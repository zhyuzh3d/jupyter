# %%
url='https://www.zhipin.com/c101020100/h_101020100/?query=%E4%BA%BA%E5%B7%A5%E6%99%BA%E8%83%BD&page='
headers={
  'user-agent':'Mozilla/5.0'
}
hud=['页数','职位名','薪资1','薪资2','地点','经验','学历','公司行业','融资阶段','公司人数','发布日期','发布人','详情']
print('\t'.join(hud))

import requests
from bs4 import BeautifulSoup
import time
headers2={
  'user-agent':'Mozilla/5.0',
  'referer':'https://www.zhipin.com/c101020100/h_101020100/'
}
def getDetails(link):
    xq_html=requests.get('https://www.zhipin.com'+link,headers=headers2)
    xq_soup= BeautifulSoup(xq_html.text, 'html.parser')
    miaoshu=''
    try:
        miaoshu=xq_soup.find('div','job-sec').find('div','text').text #获得标记的内部文字
        miaoshu=miaoshu.lstrip().rstrip() #去除开头和结尾的空格
    except:
        miaoshu='None'
    return miaoshu 

for n in range(1,21):  
    html=requests.get(url+str(n),headers=headers)
    soup = BeautifulSoup(html.text, 'html.parser')
    liebiao=soup.find_all('div','job-primary')
    for item in liebiao:
      shuchu=[]
      shuchu.append(str(n))
      shuchu.append(item.find('div','job-title').string) #职位名
      
      xinzi=item.find('span','red').string
      xinzi=xinzi.replace('k','')
      xinzi=xinzi.split('-')
      shuchu.append(xinzi[0]) #薪资起始数
      shuchu.append(xinzi[1]) #薪资起始数
      
      yaoqiu=item.find('p').contents
      shuchu.append(yaoqiu[0].string  if len(yaoqiu)>0 else 'None') #地点
      shuchu.append(yaoqiu[2].string  if len(yaoqiu)>2 else 'None') #经验
      shuchu.append(yaoqiu[4].string  if len(yaoqiu)>4 else 'None') #学历
      
      gongsi=item.find('div','info-company').find('p').contents
      shuchu.append(gongsi[0].string  if len(gongsi)>0 else 'None') #公司行业
      shuchu.append(gongsi[2].string  if len(gongsi)>2 else 'None') #融资阶段
      shuchu.append(gongsi[4].string if len(gongsi)>4 else 'None') #公司人数
      
      shuchu.append(item.find('div','info-publis').find('p').string.replace('发布于','')) #发布日期
      shuchu.append(item.find('div','info-publis').find('h3').contents[3].string) #发布人
      
      #读取每个职位的详细信息页面
      link=item.find('div','info-primary').find('h3').find('a')['href']
      xq=getDetails(link)
      shuchu.append(xq)      
      print('\t'.join(shuchu))
      time.sleep(0.2)
# Out:
# 页数	职位名	薪资1	薪资2	地点	经验	学历	公司行业	融资阶段	公司人数	发布日期	发布人	详情
# 1	汽车AI绘图员	5	6	上海 浦东新区 世纪公园	应届生	中专/中技	汽车生产	不需要融资	500-999人	09月17日	招聘经理	1、按照要求和标准对汽车的备件目录图片\备件照片\维修手册图片进行电脑描摹；职位要求：1、中专及以上学历，应届生亦可，或1年以上工作经验；2、熟练使用相关图例软件者优先,例如Adobe Illustrator；工作时间：8:30-17:00（双休）
# 1	AI项目经理	15	20	上海 长宁区 古北	3-5年	本科	互联网	B轮	100-499人	08月08日	招聘者	【岗位诱惑】：人工智能行业，不打卡，年度旅游，免费零食，弹性工作，项目奖金等。【工作职责】：1.负责AI业务的研发项目全过程管理、客户接入及线上业务运营管理；2.负责项目计划的制定、跟踪和维护、项目资源的协调与组织，确保项目按计划完成及项目目标达成；3.与研发运维团队紧密合作，推动研发运维团队流程制度的优化改进；4.负责项目的需求变更管理，控制项目风险，客户满意度管理；5.负责交付上线后跟踪优化及效果反馈，形成产品研发与优化闭环。【任职要求】：1.全日制本科及以上学历，3-5年项目管理经验，3年以上金融行业经验；2.具备从0到1的金融实施项目交付经验，智能客服机器人项目优先考虑；3.工作有激情，能吃苦，较强的自驱动能力，具备强烈的责任心；4.思路清晰敏捷，能够应对综合的跨团队、部门协调和项目管理工作；5.具有PMP证书或其它项目管理资质认证；
# 1	AI研发工程师	15	30	上海 杨浦区 江湾	1-3年	本科	互联网	已上市	1000-9999人	03月14日	系统架构师	工作职责结合AI新技术，进行视频自动化内容理解、审核等系统的设计研发工作。与AI策略工程师配合，保证AI技术的落地，通过设计实现的系统，提升b站的审核效率，并提供更好的内容理解输出(如封面图推荐、Tag视频描述等)精通C/C++语言，熟练掌握至少一种脚本语言(Python优先）有良好的数据结构和算法设计基础加分项具备海量数据处理、大规模分布式系统开发经验熟悉分布式系统原理，有分布式系统设计和开发熟悉主流大数据处理技术（hadoop/spark等）
# 1	人工智能	10	11	上海 徐汇区 田林	3-5年	学历不限	医疗健康	A轮	100-499人	07月02日	招聘者	1 熟悉采用tensorflow解决实际问题，包括图像识别，文本识别。2 熟悉tensorflow相关接口，能够与java程序员对接。3 了解tensorflow需要的训练集，指导相关人员进行数据集的整理4 精通python语言，熟悉java语言5 对医疗项目有经验的优先
# 1	人工智能讲师	30	50	上海 浦东新区 源深体育中心	1-3年	硕士	在线教育	C轮	100-499人	06月11日	HR人事	岗位职责：1、负责人工智能课程体系的设计、研发、优化；2、负责人工智能课程项目、案例的研发与讲解；3、负责人工智能日常直播答疑授课、周末授课等相关工作；4、负责人工智能课程日常学员的答疑及作业批改；5、负责完成领导安排的课程相关的其它工作。任职要求：1、硕士以上学历；2、计算机、数学或统计学相关专业；3、两年人工智能相关工作经验；4、主要从事数据挖掘,建模方向的工作；5、熟悉常用的机器学习算法 , 包括但不限于回归，聚类，时间序列，分类树，Boosting，SVM，Random Forest，神经网络，贝叶斯网络等；6、熟悉熟悉和掌握深度学习开发框架之一(如Caffe，Theano，Torch或者Keras）；7、具有较强的学习能力及良好的人际交往和沟通能力;8，能够承受工作压力，具备独立解决问题的能力和优秀的团队合作精神;9、熟悉深度学习算法（CNN，DBN， Autoencoder等）者优先 ; 有相关讲师授课经验或编程经验者优先考虑；10、具有数据清洗经验，熟悉常用的数据清洗方法；参与过完整的数据采集、数据清洗、分析和建模工作者优先；11、熟悉Cloudera、spark，impala大数据技术，具有海量数据处理和分析工作经验者优先。
# 1	人工智能讲师	25	30	上海 奉贤区 	3-5年	本科	在线教育	500-999人	None	08月28日	人事	岗位职责：1. 负责机器学习/人工智能课程体系设计和完善；2. 负责机器学习/人工智能课程的讲授；3. 负责Python机器学习部分的研究工作；4. 带领学员参加实训并指导学员完成实操项目；5. 根据学生及市场需要，高质量完成授课任务；6. 结合技术发展的发展变化，实时改进教学方法，完善教学体系；7. 完成课程辅导工作，解答学员课程疑问，保证学员的学习质量；8. 参与教学项目案例研发工作，配合完成相关的教学资料的研发工作；9. 根据学校教学发展方向对课程体系进行研讨；10. 团队安排的其它相关工作。职位要求：1. 本科，计算机相关专业，扎实的计算机基本功及数学基础，品行端正，无不良嗜好，不抽烟饮酒；2. 熟悉至少一种深度学习常用框架，如TensorFlow，PyTorch。在机器学习、智能决策、自然语言处理、语音识别、图像识别等领域有研究或项目经历优先；3. 熟悉机器学习常用算法和原理，如线性回归、逻辑回归、SVM、kmeans、决策树等；4. 熟悉至少一种深度学习模型 如CNN、RNN、KNN等，并掌握相关优化方案；5. 具有较强编程能力，熟练使用python；
# 1	AI研究员	25	50	上海 闵行区 	1-3年	博士	计算机软件	天使轮	20-99人	06月04日	技术经理	【职位描述】从事1-3中之一的研究与开发任务：1.	展开深度学习或者强化学习等领域的技术研究与应用开发；2.	展开图形图像、机器视觉领域的核心算法研究与应用开发；3.	展开上述算法与机器人视觉系统的结合产品研发，针对机器人产品的特殊需求展开系统级开发；4.	具体的包括：负责从事深度学习框架搭建、与视觉相关类的机器学习等算法开发与调优、核心应用系统开发，开发包括机器人视觉系统、其它3D机器视觉系统在内的相关核心技术；5.	与产品开发组工程师一起，负责核心算法系统的升级开发与优化，实现产品开发周期升级迭代；【职位要求】1. 熟悉深度学习框架和算法、熟悉常用机器学习算法，有相关研究或项目经验；具有机器视觉开发经验更佳2. 深刻理解统计机器学习/最优化理论，在图像处理、视觉领域上有一定经验更好3. 掌握深度学习常用模型的实现和优化方法4. 熟练掌握Tensorflow或其它类似深度学习平台的使用5. 精通C++/Python，熟悉Linux工作环境，对数据结构和算法设计有深刻理解6. 有分布式算法、GPU等平台上开发经验；熟悉Hadoop或者Spark框架更佳
# 1	AI工程师	15	25	上海 杨浦区 江浦路	3-5年	硕士	互联网	天使轮	0-20人	07月24日	CEO	1.负责机器学习、计算机视觉、图像处理，语义理解等算法研究；2.负责算法在产品中的落地；3.负责机器学习算法的性能优化、难点攻关与前瞻研究；任职要求：1. 计算机、数学或模式识别等相关专业，硕士或博士学历；2. 掌握机器学习/深度学习，熟悉PadlePadle框架。
# 1	AI产品经理	16	30	上海 普陀区 金沙江路	1-3年	本科	智能硬件	不需要融资	20-99人	03月21日	CEO	职位描述：1.	发现并理解市场上对计算机视觉、AI产品的需求，并设计相关产品进行解决。2.	对计算机视觉、AI技术和市场趋势持续关注，注重创新。技术需求指标：1.	图像处理、计算机视觉相关专业。2.	熟悉各类图像处理、分析软件的使用。3.	熟悉常见的机器学习算法模型，如Adaboost、SVM、LR等。4.	熟悉常见深度学习网络结构，了解 GPU等异构计算的概念。加分项：1.	有完整跟进过一个或多个视觉产品项目者优先。2.	有完整跟进过一个或多个AI产品功能项目者优先。3.	有AI、计算机视觉算法技术背景者优先。
# 1	无人驾驶AI专家	25	50	上海 闵行区 浦江	3-5年	本科	智能硬件	天使轮	0-20人	09月20日	招聘者	探索深度学习，以及其他深度学习方法在无人驾驶领域的应用，包含：- 图像信号处理- 时序信号处理- 强化学习
# 1	AI及大数据研发总监	30	60	上海 杨浦区 长白新村	5-10年	本科	企业服务	已上市	100-499人	08月22日	高级副总裁	负责人工智能及大数据技术在公司新产品研发中的应用开发精通自然语言处理，ocr，知识图谱，规则引擎，大数据技术框架，机器学习5年以上相关工作经验能代领团队独立完成技术落地
# 1	人工智能（AI）讲师	20	40	上海 浦东新区 源深体育中心	3-5年	硕士	在线教育	C轮	100-499人	07月12日	HR	岗位职责：1、负责人工智能课程体系的设计、研发、优化；2、负责人工智能课程项目、案例的研发与讲解；3、负责人工智能日常直播答疑授课、周末授课等相关工作；4、负责人工智能课程日常学员的答疑及作业批改；5、负责完成领导安排的课程相关的其它工作。任职要求：1、硕士以上学历；2、计算机、数学或统计学相关专业；3、两年人工智能相关工作经验；4、主要从事数据挖掘,建模方向的工作；5、熟悉常用的机器学习算法 , 包括但不限于回归，聚类，时间序列，分类树，Boosting，SVM，Random Forest，神经网络，贝叶斯网络等；6、熟悉熟悉和掌握深度学习开发框架之一(如Caffe，Theano，Torch或者Keras）；7、具有较强的学习能力及良好的人际交往和沟通能力;8，能够承受工作压力，具备独立解决问题的能力和优秀的团队合作精神;9、熟悉深度学习算法（CNN，DBN， Autoencoder等）者优先 ; 有相关讲师授课经验或编程经验者优先考虑；10、具有数据清洗经验，熟悉常用的数据清洗方法；参与过完整的数据采集、数据清洗、分析和建模工作者优先；11、熟悉Cloudera、spark，impala大数据技术，具有海量数据处理和分析工作经验者优先。
# 1	人工智能产品经理-实习	6	7	上海 浦东新区 梅园	应届生	硕士	互联网	不需要融资	1000-9999人	08月13日	招聘者	实习内容：协助开展并推进集团核心项目工作。1、协助进行智慧金融/智慧医疗/智慧城市相关人工智能行业调研、竞品分析等任务2、协助进行项目管理，沟通推进重点项目进展3、协助制作给平安集团领导/业务方领导汇报材料及数据分析报告4、协助完成业务方需求的分析、功能和原型设计、需求文档撰写等产品相关工作技能要求：对人工智能与大数据基本理论知识、医疗/金融行业有一定理解和认识对数据敏感，能够快速收集各渠道有价值的信息来源逻辑清晰，表达能力强，具有强大的执行力，能快速响应并积极主动完成任务，善于思考和总结熟练运用PPT/EXCEL，能够使用Xmind、Axure、Visio等工具有产品需求分析、原型设计经验者优先有医疗/金融或咨询行业学习或实习背景优先有学生工作经验者或社团负责人优先实习时间：每周至少实习4天，至少实习３个月，优先考虑大三或研二的同学实习待遇：研究生300元/天、本科生200元/天工作地点：上海
# 1	人工智能顾问	10	15	上海 浦东新区 源深体育中心	经验不限	大专	在线教育	C轮	100-499人	06月11日	HR人事	岗位职责：1、负责人工智能课程日常学员的答疑以及作业批改；2、负责人工智能课程日常直播答疑课程等相关工作；3、参与人工智能课程项目、案例的研发与讲解；4、负责完成领导安排的其它课程相关工作。任职要求：1、大专以上学历，24-30岁之间；2、计算机或者统计学相关专业；3、3年以上计算机相关从业工作经验，具有人工智能相关工作经验者优先；4、现阶段主要从事人工智能方向的研发,教学等工作；5、具有较强的学习能力及良好的人际交往和沟通能力；6，能够承受工作压力，具备独立解决问题的能力和优秀的团队合作精神；7、有相关讲师授课经验者优先考虑；8、熟悉常用机器学习算法、深度学习算法者优先考虑。
# 1	人工智能开发工程师	25	35	上海 浦东新区 张江	3-5年	本科	移动互联网	D轮及以上	1000-9999人	08月19日	招聘经理	岗位职责：1.利用深度学习技术进行前沿人工智能技术研发；进行人工智能相关前沿算法的研究，包括机器学习、知识图谱等技术的研究；2.负责深度学习，强化学习平台的选型，框架搭建，开发及优化3.探索研究人工智能在自适应学习的应用；开发基于互联网教育大数据的人工智能应用系统和平台。4.开发自然语言处理（NLP）应用系统，负责模型算法的工程化实现、服务接口的实现。 任职要求：     1.专业不限、背景不限；仅限对人工智能、机器学习及互联网教育有浓厚兴趣和充满热情，有的责任心、好奇心。     2.熟悉深度神经网络的常用模型（CNN、RBN、RCNN、DNN等），并能够将其应用特定场景中；熟练掌握常用的统计机器学习算法（神经网络、逻辑回归、决策树、SVM、Boosting等）     3.具有熟练的编程能力，熟悉Java或C++或Python、主流开发框架，有大型项目的开发经验和工作能力。     4.有机器学习的算法基础和经验优先，有NLP经验优先，熟练使用Caffe、Theano、Torch、Tensorflow等任一种主流的深度学习框架优先。
# 1	AI智能课程销售	10	20	上海 徐汇区 漕河泾	1年以内	大专	互联网	A轮	1000-9999人	09月16日	招聘主管	职位描述：1.根据公司提供的客户源及已在官网报名的学生家长进行沟通咨询服务，安排合适的试听课；2.收集学生试听课反馈信息，为其安排个性化课程，推荐符合的课程套餐，最终完成报名；3.根据公司发展规划，持续完成每月销售指标； 岗位要求：1. 大专（含）以上学历，营销、管理、教育、心理学等专业优先；（能力优秀者可适当放宽）2.热爱教育行业，致力于长期在教育行业发展；3.亲和力强、沟通流畅、有较强的服务意识和责任心；4.工作积极主动、能够承受压力、勇于挑战高薪5.优秀应届毕业生亦可6..能够接受教育类行业的灵活上班时间，偏向于下午晚上和周末上班（交通十分便利） [薪酬福利]： 1.无责底薪5000-12000，有同行经验可面谈，提成最高4-16个点，加额外奖金；打车补贴；2.底薪可根据实际业绩调整，公司提供快速晋升通道；3.根据公司提供的生源外呼，无需自己外出挖掘开发；4.签订劳动合同，入职即缴纳五险一金；5.工作环境舒适，靠近地铁站，交通十分便利；[晋升通道]：1.专业销售路线：初级 -> 中级 -> 资深；2.销售管理路线：课程顾问-资深课程顾问-课程顾问主管-课程顾问经理-课程顾问总监3.内部晋升职位：公司招募职位以内部竞选员工优先，存在其他部门发展通道[交通]：地铁9号线,桂林路站地铁12号线,虹漕路站 均可到达
# 1	AI产品经理	20	40	上海 徐汇区 枫林路	3-5年	本科	移动互联网	不需要融资	1000-9999人	09月19日	招聘者	职位名称：智能化科技服务产品经理 职位优势：l   平安集团下属子公司，500强集团公司背景，完善的金融牌照实力，良好的政府关系，BAT背景管理团队、房地产及金融热门行业 职责范围：l   负责公司AI智能化产品的规划和落地，支持AI产品在公司各云服务的智能化实际落地应用。l   负责区块链在房产租赁交易以及各外延的应用，设计底层区块链产品，支持上层产品应用在效率、安全、价值提升l   制定产品版本计划，协调设计、研发、测试，推动产品的迭代开发进程，跟进上线运营情况，根据数据反馈持续优化产品。l   对行业进行跟踪和洞察，及时了解市场动态，制定优化和迭代计划。 资质要求：l   本科及以上学历，985/211学校优先，1~5年互联网、软件行业产品经理相关背景，有人工智能产品、区块链产品、物联网IoT类产品设计经验。l   逻辑思维能力：能从复杂业务中提炼结构化、标准化需求，并制定相应产品迭代方案。l   沟通协调能力：能与业务、运营、研发、测试等多个岗位进行跨团队、跨公司的高强度沟通，并能有效协调不同团队资源。l   项目管理能力：能管理负责大型项目的研发迭代进程和节奏，并及时发现项目进程风险并加以处理。
# 1	AI训练师	8	16	上海 长宁区 古北	经验不限	本科	互联网	B轮	100-499人	09月02日	招聘经理	岗位职责：1、负责智能客服机器人知识库的设计与构建；2、负责智能客服机器人标注数据的优化；3、负责行业数据的积累及公司内部研发所需的数据支持。岗位要求：1、全日制本科及以上学历，有数据标注或客服经验，及保险/证券/基金背景的优先；2、具有良好的学习能力、沟通表达能力、理解能力和逻辑思维能力；3、优秀的数据分析能力，对数据整理工作有热情；4、心思细腻有耐心，主动性强，富有责任感；5、接受出差安排；6、大学英语六级以上，会小语种者优先。
# 1	人工智能研究员	35	70	上海 徐汇区 虹梅路	经验不限	学历不限	企业服务	0-20人	None	03月30日	总经理	解决人工智能在企业落地的刚性需求，包括但不限于计算机视觉，自然语言处理，最优化，以及大规模营销，并针对部分领域展开预研和攻关。团队获得百万人脸识别冠军，并在多项Kaggle竞赛中获得金银牌，目前正致力于算法落地。我们希望候选人具备一定经验的深度学习框架应用水平和相当的调参能力，例如MXNet，PyTorch以及TensorFlow等，当然，我们更加看重候选人对机器学习和深度学习原理的了解以及针对无数论文去伪存真并实现代码的能力。对于能够编写底层operator，对深度学习压缩剪枝或者迁移学习有深厚造诣的我们尤其欢迎。
# 1	AI产品全栈工程师	20	30	上海 杨浦区 江浦路	5-10年	硕士	互联网	天使轮	0-20人	07月24日	CEO	工作职责负责人工智能房地产产品的设计、研发和维护对新技术和方案进行调研、评估和引进，用技术提升研发效率岗位要求计算机相关专业，硕士及以上学历有5年以上编程经验，独立完成过中等规模的项目精通HTML/HTML5/CSS3/Javascript/JQuery/Ajax等前端技术，熟悉W3C标准精通Python或任意一种脚本语言有良好的数据结构和算法设计基础熟悉Linux系统原理、熟练运用Linux命令与脚本熟悉关系型数据库原理及SQL语言有独立完成产品的架构设计、开发、测试和部署的能力加分项对ReactJS, AngularJS, Vue或其他前端MVC框架有使用经验者优先对Django, Flask或其他Web框架有使用经验者优先熟悉多平台开发，Linux 服务端，PC或Mac端，iOS 或 Android 移动端掌握至少一门原生语言者优先具备人工智能/大数据+房地产相关背景、研发经验者优先
# 1	人工智能算法工程师讲师	25	30	上海 浦东新区 世纪公园	1-3年	硕士	在线教育	C轮	100-499人	09月11日	招聘主管	岗位职责：1.负责人工智能、机器学习和算法课程教学工作，按进度完成教学任务；2.根据需要，改进教学方法，完善教学体系；3.参与学术交流与研讨，不断提升业务水平任职资格；4.参与进行AI项目课程研发和后期优化；5.参与完成教学相关的文档编写工作(教学ppt，教案文档等)；6.配合兄弟部门完成技术沙龙类的讲座活动；7.完成领导临时交办的其他工作。任职要求：1、相关专业毕业；对人工智能、机器学习有扎实的理论功底和实践经验；2、熟悉深度神经网络的常用模型（CNN、RBN、RCNN、DNN等），并能够将其应用特定场景中；熟练掌握常用的统计机器学习算法（神经网络、逻辑回归、决策树、SVM、Boosting等）；3、具有熟练的编程能力，熟悉Java或C++或Python、主流开发框架，有大型项目的开发经验和工作能力；4、有机器学习的算法基础和经验优先；5、具有较强的学习能力及良好的人际交往和沟通能力；6，能够承受工作压力，具备独立解决问题的能力和优秀的团队合作精神；7、有相关讲师授课经验者优先考虑。
# 1	人工智能高级专家	30	50	上海 徐汇区 徐家汇	3-5年	硕士	数据服务	20-99人	None	08月15日	执行院长	主要职责： 1 开发面向数据集成的机器学习、自然语言理解、知识图谱、检索与推荐的算法 ；2 负责团队的人员发展、激励和培养； 3 与合作企业及上海交通大学人工智能研究院课题组开展产学研合作，负责科研成果的快速工程化 ；4 配合研究院对接应用需求，结合实际场景，组织各方资源，实现创新落地 。任职要求：1 计算机、电子信息工程、自动化控制、统计等相关专业背景，硕士及以上学历； 2 在以下至少一个领域有深入研究和系统实现经验，及三年以上的工作项目经历： 大规模机器学习；搜索/推荐引擎；自然语言理解；深度学习/图数据库等。 3 熟悉一个或多个常见的 NLP/ML/DL 开源工具库，如Caffe、Tensorflow等，能够快速实现新的想法； 4 有较强的学习创新和逻辑思维能力，责任心强,对技术有强烈的进取心，具有良好的沟通能力和团队合作精神。5 博士学历以上的应聘者，特别优秀者且对研究有兴趣者，可直接转校内上海交通大学人工智能研究院应聘。
# 1	C++高级工程师（AI方向）	20	35	上海 闵行区 	5-10年	硕士	计算机软件	天使轮	20-99人	08月29日	技术总监	职责描述：1、负责AI深度学习、机器学习及机器视觉相关产品的技术预研、文档编写等2、负责AI深度学习、机器学习及机器视觉相关产品的代码实现、研发、自动化测试等3、参与相关的架构设计、代码Review、产品软件系统的性能优化等任职要求：1.	研究生及以上学历，计算机、电子工程或者数学专业，5年以上工作经验2.	扎实的计算机基础，熟练掌握数据结构、算法等知识3.	精通C++语言，有QT或MFC界面开发经验，熟悉WIN系统API，有网络、多线程编程经验，足够的代码量积累，代码风格良好4.	熟悉Python或者go其中一种语言，愿意并可快速掌握新的开发语言及工具 5.	熟悉面向对象的软件设计及设计模式，熟悉UML、数据库设计相关工具6.	精通数据模型的设计优化，熟练使用MySQL及MongoDB数据库7.	熟悉Git工作流，具备研发团队管理经验8.	除熟悉Linux平台下开发、熟练使用常用Linux命令优先条件：1.	有AI包括机器学习、深度学习、大数据等研发经验，熟悉TensorFlow2.	精通Qt应用程序图形界面开发，熟悉掌握Qt库各控件使用及架构3.	熟悉OpenCV或Matlab图像处理开发、使用经验4.	对代码、AI有极大的热情，有过大型产品设计经验，对易用性和视觉感有较高要求
# 1	AI前端工程师	10	20	上海 浦东新区 张江	3-5年	本科	移动互联网	A轮	100-499人	08月27日	人事专员	职位描述：1、负责人工智能产品的设计与实现2、负责复杂数据可视化设计与实现3、根据视觉设计图实现前端web页面职位要求：1、本科及以上学历，至少3年以上前端开发经验2、熟悉html/html5/css/css3/less/sass，对静态页面实现有一定经验和理解3、了解数据可视化技术，熟悉BI数据展现4、精通一种前端框架如angular、react,vue等5、熟悉页面架构和布局，对数据表现与有深刻理解，熟悉bootstrap者优先6、熟练掌握js或者typescript者优先7、了解机器学习，对机器学习和深度学习有浓厚兴趣8、对CSS/JS性能优化、解决多浏览器兼容性问题有一定经验9、对用户体验、交互操作流程设计、及用户需求有深入理解有强烈的上进心和求知欲，善于学习和运用新知识，有良好的团队意识和执行力。
# 1	在线AI智能教学初中老师	8	15	上海 徐汇区 漕河泾	1年以内	本科	互联网	A轮	1000-9999人	06月28日	招聘专员	[岗位职责]：1.负责智适应学习平台在线1对1课程的教学任务；2.为学员提供课程相关的学习指导与学术答疑，完成教学质量分析；3.维护学员关系，及时处理学员需求，提升学员学习动力；4.参与学科教学培训和课程教研工作，提高自身教育水平和教学能力；5.收集学员反馈与教学信息，协助研究院优化教学设计及教学产品。[任职要求]： 1.大学本科以上学历，相关教育专业优先；2.有相关学科家教、在线教育培训经验者优先；3.有团队合作意识，良好的时间管理和沟通协调能力； 4.执行力强，有一定的抗压能力，有较强的学员服务意识。
# 1	人工智能产品策划	12	20	上海 静安区 共和新路	经验不限	本科	医疗健康	已上市	1000-9999人	08月31日	招聘者	工作职责：1. 了解用户需求，掌握市场动态，2. 协同完善人工智能相关产品的文档材料撰写3. 协调并组织设计、开发和测试等团队，完成标准化文档的撰写，保证产品质量4. 协助执行针对不同行业不同业务场景的市场侧竞争分析，输出相应成果5. 推动产品目标的实现，协助完成演示demo的开发职位要求：1.具备良好的书面表达能力和逻辑思维能力，具有主动的沟通能力和团队协作能力2. 具有较强的交互设计且一定的视觉设计能力，能按时给出高质量的产品原型、流程图、线框图，清晰的表达自己的设计方案；3. 具有良好的宏观把控能力，有在IT、互联网行业从事相关实习经验者优先4. 对人工智能相关方面有兴趣，愿意主动接触新事物和内容5. 具备优秀的学习能力和抗压能力6. 本科以上学历，理工科专业优先
# 1	人工智能技术顾问	10	15	上海 浦东新区 世纪公园	1-3年	大专	在线教育	C轮	100-499人	09月11日	招聘主管	岗位职责：1、负责人工智能课程日常学员的答疑以及作业批改；2、负责人工智能课程日常直播答疑课程等相关工作；3、参与人工智能课程项目、案例的研发与讲解；4、负责完成领导安排的其它课程相关工作。任职要求：1、大专以上学历，24-30岁之间；2、计算机或者统计学相关专业；3、3年以上计算机相关从业工作经验，具有人工智能相关工作经验者优先；4、现阶段主要从事人工智能方向的研发,教学等工作；5、具有较强的学习能力及良好的人际交往和沟通能力；6，能够承受工作压力，具备独立解决问题的能力和优秀的团队合作精神；7、有相关讲师授课经验者优先考虑；8、熟悉常用机器学习算法、深度学习算法者优先考虑。
# 1	人工智能（深度/机器）学习讲师	20	40	上海 浦东新区 源深体育中心	3-5年	硕士	在线教育	C轮	100-499人	07月12日	HR	1、负责或参与人工智能课程体系的设计、生产、优化；2、负责或参与人工智能课程项目、案例的研发与讲解；3、负责或参与人工智能课程日常学员的答疑及作业批改；4、负责或参与人工智能课程线上试学体验工作；任职要求：1、硕士及以上学历；2、计算机、数学或统计学相关专业；3、两年人工智能相关工作经验4、主要从事数据挖掘,建模方向的工作；5、熟悉常用的机器学习算法 , 包括但不限于回归(Logistic)，聚类，时间序列，分类树，Boosting，SVM，Random Forest，神经网络，贝叶斯网络等6、熟悉熟悉和掌握深度学习开发框架之一(如Caffe，Theano，Torch或者Keras）；7、具有较强的学习能力及良好的人际交往和沟通能力;8，能够承受工作压力，具备独立解决问题的能力和优秀的团队合作精神;9、熟悉深度学习算法（CNN，DBN， Autoencoder等）者优先 ; 有相关讲师授课经验或编程经验者优先考虑；10、具有数据清洗经验，熟悉常用的数据清洗方法；参与过完整的数据采集、数据清洗、分析和建模工作者优先；11、熟悉Cloudera、spark，impala大数据技术，具有海量数据处理和分析工作经验者优先。
# 1	AI产品经理	15	25	上海 杨浦区 周家嘴路	1-3年	本科	移动互联网	C轮	1000-9999人	09月01日	招聘经理	岗位职责:负责人工智能产品整体规划、阶段目标、产品设计和推进实现；与业务线产品经理、内容、技术等团队充分沟通协作，保证产品功能落地；产品上线后，分析使用数据，提炼使用场景，找到产品改进点和突破点，用丰富的交互场景推动 AI 创新；对用户的交互使用体验负责；负责行业市场分析、用户需求调研和竞品分析工作；任职要求：1年以上 AI 相关产品经验；善于系统性思考、分析问题；出色的用户痛点挖掘能力；加分项：对于英语学习有思考和兴趣。
# 1	人工智能讲师	20	40	上海 普陀区 华师大	经验不限	本科	在线教育	未融资	1000-9999人	06月20日	招聘者	岗位职责： 1、负责人工智能课程日常学员的答疑以及作业批改；2、负责人工智能课程日常直播答疑课程等相关工作；3、参与人工智能课程项目、案例的研发与讲解；4、负责完成领导安排的其它课程相关工作；任职要求：1、硕士以上学历，28-40岁之间。 2、计算机或者统计学相关专业 4、熟悉常用的机器学习算法 , 包括但不限于回归，聚类，时间序列，分类树，Boosting， Random Forest，神经网络，贝叶斯网络等；5、具有较强的学习能力及良好的人际交往和沟通能力;6、能够承受工作压力，具备独立解决问题的能力和优秀的团队合作精神;7、有相关讲师授课经验者优先考虑；8、熟悉常用机器学习算法、深度学习算法者优先考虑；
# 2	人工智能工程师	20	30	上海 浦东新区 张江	经验不限	本科	互联网	不需要融资	500-999人	03月15日	招聘者	"职责描述：1. 基于ARM平台的嵌入式系统机器视觉、语音方面的应用开发、调试和优化;2. 在Caffe/MXnet/Tensorflow等开源框架下针对应用场景的软件需求定义和开发3. 负责芯片内集成AI/NN硬件模块的驱动开发，维护以及Bringup工作等等任职要求：1. 本科以上学历，具有5年以上从事相关人工智能应用算法、软件开发和调试优化经验；2. 熟悉Linux/Android，精通Linux下C/C++和Python编程及调优；3. 熟悉深度神经网络和常用的模型,如RBM、CNN、DBN、Sparsecoding、RNN等4. 熟悉Tensorflow/Caffe/MXnet/CNTK等至少一种开源框架的使用；5. 有openCV和openCL开发经验者尤佳6. 工作责任感强，踏实勤奋，有较强的钻研精神和团队合作精神"
# 2	Android系统工程师（AI工程化）	15	25	上海 徐汇区 枫林路	5-10年	本科	互联网	不需要融资	10000人以上	08月17日	招聘者	Basic要求：  1. 熟悉Android框架，具有软件架构设计能力，涉及Native/Kernel/Framework/APP多层次模块; 2. 以下全部或部分领域有研发经验：Activity Manager Service，Package Manager Service，Windows Manager Service，Location Manager Service，Power Manager Service，Battery Status，Alarm Manager，ART/GC，Stagefright, Telephony Service; 3. 熟练使用android常规调试工具，熟练JNI、Binder、Socket等相关开发； 4. 精通C/C++，熟悉Java、Python、Shell等一种以上编程语言 Preferred要求：  1 独立进行过Native/Framework软件架构代码开发者优先 2对Android性能优化工作有深入了解者优先 3 对Linux内核有深入了解者优先 4 对深度学习或机器学习算法有一定了解者优先 5对人工智能基本原理和建模优化工作有一定了解者优先
# 2	产品经理（人工智能方向）	6	12	上海 静安区 静安寺	1-3年	大专	房地产开发	不需要融资	500-999人	08月06日	招聘经理	岗位职责：1、 与公司业务部门对接，梳理人工智能各类场景。2、 参与售后智能对话的设计，参与智能对话外围系统的设计。3、 收集业务部门的反馈数据，发现存在问题、提出解决方案并能迅速推进产品优化。4、 负责公司平台大数据产品的战略规划和设计工作，设计原型、撰写产品需求文档5、 洞悉客户需求、梳理业务流程、深度挖掘行业需求，分析问题并提出创新解决方案任职资格：1、 全日制本科及以上学历，计算机相关专业优先。2、 两年及以上产品设计经验，有互联网产品经验者优先。3、 有呼叫中心产品设计经验，有智能客服产品经验者优先。3、 出色的跨团队沟通协调能力，以及良好的组织能力和学习能力。4、 思路清晰，可与业务和技术团队紧密配合，且高效推动产品生命周期各阶段的执行。
# 2	人工智能高级研究员	50	100	上海  	5-10年	硕士	医疗健康	未融资	1000-9999人	04月05日	招聘者	Position Description: - Lead the definition of architectures and development of artificial intelligence platform for real-world applications.- Responsible for deep learning related technology innovation and prospective study.- Develop best practices for cloud based artificial intelligence, which includes computer vision, NLP, speech recognition, etc.Position Requirements: 1. PhD or master in computer science or related fields with high experience building artificial intelligence system for real-world applications.2. Highly experienced with one of mainstream deep learning Toolkits, such as Caffe, TensorFlow, Theano, Torch. TensorFLow is preferred .3. Experience in distributed system design and implementation.4. Deep Knowledge about artificial intelligence technologies and methods/tools.5. Deep Knowledge in one of CV, NLP, Speech recognition etc. and will be preferred.6. Have excellent R&D management experiences and good team spirit.
# 2	人工智能运营专员	6	12	上海 虹口区 鲁迅公园	1-3年	本科	互联网金融	已上市	500-999人	08月01日	HR	工作职责： 1. 负责AI机器人知识库的规划和建设，保证机器人的准确率； 2. 负责知识的优化和运营工作，包括知识修改及新增； 3. 通过数据分析和内容分析，能及时提出优化方案和对产品经理提出合理的需求； 任职资格：1.全日制本科，金融相关专业 2. 有较好的逻辑分析能力和文字处理功底； 3. 并具有较强的执行力和交流、沟通能力
# 2	机器人，app软件android软件，人工智能软件	8	16	上海 长宁区 天山路	3-5年	本科	智能硬件	A轮	20-99人	06月22日	CEO	岗位职责：1、负责手机网络应用客户端的开发，分别基于Android平台进行手机软件的设计、开发、需求分析等；2、负责服务器模块设计、手机客户端与服务器端的通讯设计与开发；3、与项目相关人员配合共同完成手机客户端应用软件的开发设计工作；4、进行源代码的单元测试和质量控制。职位要求:1、大学本科学历，计算机、电子信息技术及其相关专业；2年以上相关工作经验。2、精通JAVA/C/C++语言，对面向对象的开发有深刻认识；3、熟悉Android平台的应用开发，熟悉平台的相关接口；4、深刻理解网络通讯原理，有实际的网络通讯程式开发经验，深刻了解各种网络协议；精通TCP/IP、Socket等网络通信编程技术；5、具有诚实、乐观、富于责任感的精神；良好的职业道德和积极向上的心态；6、善于沟通交流，有良好的团队协作精神和服务意识。
# 2	AI产品经理/数据产品经理	20	40	上海 浦东新区 	3-5年	硕士	互联网金融	已上市	10000人以上	05月20日	AI团队负责人	职位描述：此职位主要负责数据平台产品规划、推动、落实、上线，为业务提供高效的数据平台产品。工作职责：1、管理和分析业务方数据需求，规划数据平台整体建设目标，支持业务团队数据需求；2、主导数据产品的研发、与分析师、数据开发、业务方紧密合作，挖掘数据价值，形成数据产品；3、业务团队与技术团队的沟通桥梁，通过深入了解业务需求，形成PRD相关文档，协助技术开发满足数据要求。4、制定数据产品运营策略，协调部门及业务方持续改善产品功能和使用体验，提高决策效率。5、组织跨团队协作，保证项目如期上线；任职资格：1、本科以上学历，3年以上相关工作经验， 985或211学校;2、有产品设计或分析经验，能够独产承担产品规划工作；3、具备良好的数据敏感度和业务视野，能够敏锐的捕获数据价值和产品机会；4、了解底层数据的架构技术以及应用层数据分析和算法的基本概念，能够运用数据作为产品解决业务方运营及决策问题；5、有参与过大型项目或系统建设的经验，有流量分析系统、管理决策系统、经营分析系统建设经验者优先考虑；6、沟通能力强、有团队合作精神，精通项目管理和团队协调；7、 具有技术背景，有java、python、R等开发经验，有机器学习算法应用经验者优先8、有深度学习、强化学习、对抗学习应用产品实现经验者优先9、具有银行或互联网数据产品经验者优先；
# 2	自然语言（人工智能）开发工程师	15	30	上海 浦东新区 张江	经验不限	本科	移动互联网	A轮	20-99人	04月01日	招聘者	职位描述：1、利用NLP/ML等相关技术和算法，提供文本分析相关的基础方案与服务； 2、针对海量文本内容进行中文分词、语义识别、自动聚类等文本挖掘工作； 3、负责搭建相关的机器学习 & 大数据计算平台4、负责数据和业务的紧密集合任职条件 ：1、2年以上相关经验，计算机、数学及相关专业本科以上学历，机器学习、自然语言处理、用户画像等算法研究方向优先； 2、了解自然语言处理基础理论和方法，了解中文分词、语义分析、文本聚类、实体识别等基础算法和应用； 3、JAVA\python\c\c++\R等，至少熟练掌握一种编程语言，有linux环境开发经验； 4、有Hadoop、spark等分布式平台建模或算法开发经验优先； 5、有深度学习研究与应用经验优先；6、有相关经验的优秀应届生也可考虑
# 2	人工智能产品实习生	12	13	上海 静安区 共和新路	经验不限	本科	医疗健康	已上市	1000-9999人	08月27日	招聘者	1.具备良好的书面表达能力，具有主动的沟通能力和团队协作能力2. 具有较强的逻辑设计能力，清晰的表达自己的设计方案；3. 具有良好的宏观把控能力，有在IT、互联网行业从事相关实习经验者优先4. 对人工智能相关方面有兴趣，愿意主动接触新事物和内容5. 每周工作2-3天
# 2	初中数学K12在线AI智能教学	8	12	上海 徐汇区 漕河泾	1-3年	本科	互联网	A轮	1000-9999人	06月28日	HR	[岗位职责]：1.负责智适应学习平台在线1对1课程的教学任务；2.为学员提供课程相关的学习指导与学术答疑，完成教学质量分析；3.维护学员关系，及时处理学员需求，提升学员学习动力；4.参与学科教学培训和课程教研工作，提高自身教育水平和教学能力；5.收集学员反馈与教学信息，协助研究院优化教学设计及教学产品。[任职要求]： 1.大学本科以上学历，相关教育专业优先；2.有相关学科1对1在线教育培训经验者优先；3.有团队合作意识，良好的时间管理和沟通协调能力； 4.执行力强，有一定的抗压能力，有较强的学员服务意识。
# 2	Python高级工程师（AI方向）	20	35	上海 闵行区 	5-10年	硕士	计算机软件	天使轮	20-99人	08月20日	技术总监	工作职责： 1、负责AI深度学习、机器学习及机器视觉相关产品的技术调研分析、设计等2、负责AI深度学习、机器学习及机器视觉相关产品的代码实现、研发、自动化测试等3、参与相关的架构设计、代码Review、产品软件系统的性能优化等岗位要求：1.	硕士及以上学历，计算机、电子工程或者通信等专业，5年以上工作经验2.	扎实的计算机基础，熟练掌握数据结构、算法等知识3.	精通Python语言，熟悉C++或Java其中一种语言，足够的代码量积累，代码风格良好4.	精通Python Django框架或PyQt, 熟悉源码；5.	熟悉面向对象的软件设计及设计模式，熟悉UML、数据库设计相关工具6.	精通数据模型的设计优化，熟练使用MySQL及MongoDB数据库7.	熟悉Git工作流，具备研发团队管理经验8.	熟悉Linux平台下开发、熟练使用常用Linux命令优先条件：1.	有AI包括机器学习、深度学习、大数据等研发经验，熟悉TensorFlow2.	了解HTML5/CSS3、Javascript、jQuery或VUE前端技术3.	对代码、AI有极大的热情，有过大型产品设计经验，对易用性和视觉感有较高要求4.	参与过开源社区项目，有大量代码贡献
# 2	技术总监【医疗影像人工智能方向】	45	60	上海 徐汇区 虹梅路	3-5年	本科	互联网	已上市	10000人以上	07月26日	招聘者	技术总监【医疗影像人工智能方向】岗位职责：1、负责人工智能医疗影像软件技术架构的制定，负责系统技术方案整体的调研、评估、架构设计、方案设计、质量控制、开发执行；2、制定公司开发规范，参与底层框架、核心代码编写以及核心技术问题攻关；3、跟踪市场相关产品与技术发展趋势，了解竞争对手动态，负责组织和带领内部员工研究探索与产品相关的新技术；4、参与公司重点项目的咨询规划。		 任职要求：1. 本科以上学历，至少5年以上医疗信息系统开发经验，作为主要设计者承担过远程影像或者PACS产品的技术架构设计；熟悉HL7、DICOM协议，对DICOM有深入的理解；	2. 有5~10人以上的研发团队管理经验，有较好的项目管理能力；3. 精通java，并熟悉相应的生态圈，对各种开源框架如SpringMVC，iiBatis，Redis等熟悉；		4. 精通设计模式，有丰富的架构经验，对B/S, C/S模式均有了解；	5. 熟悉医院组织结构及工作流程，特别是检查/医技科室工作流程者优先；熟悉各厂商HIS, PACS等系统接口规范者优先；熟悉GDI或GDI+或OPENGL或WebGL图像编程者优先；6. 具备快速学习能力，抗压能力强；思路清晰、拥有良好的沟通和协作能力，注重培养下属。
# 2	python讲师（数据分析/人工智能）	10	15	上海 浦东新区 源深体育中心	3-5年	本科	在线教育	C轮	100-499人	05月28日	HR	None
# 2	人工智能（NLP方向）	25	50	上海 长宁区 天山路	1-3年	本科	移动互联网	已上市	1000-9999人	07月29日	招聘者	None
# 2	高级测试工程师（AI方向）	15	30	上海 闵行区 	5-10年	本科	计算机软件	天使轮	20-99人	08月01日	技术总监	None
# 2	AI研究员	25	50	上海 闵行区 	1-3年	博士	计算机软件	天使轮	20-99人	06月27日	HR	None
# 2	AI算法研究员	25	50	上海 浦东新区 世纪公园	3-5年	本科	电子商务	不需要融资	20-99人	06月25日	HR总监	None
# 2	初中语文在线AI教育教学老师	8	15	上海 徐汇区 漕河泾	1年以内	本科	互联网	A轮	1000-9999人	06月28日	招聘专员	None
# 2	AI深度学习视觉算法工程师	30	50	上海 徐汇区 漕河泾	3-5年	硕士	互联网	100-499人	None	04月09日	招聘总监	None
# 2	初中数学在线AI智能教学老师	8	15	上海 徐汇区 漕河泾	1年以内	本科	互联网	A轮	1000-9999人	06月28日	招聘专员	None
# 2	AI产品经理	15	30	上海 徐汇区 交通大学	3-5年	硕士	企业服务	A轮	100-499人	09月13日	HR经理	None
# 2	初中物理在线AI教育教学老师	8	15	上海 徐汇区 漕河泾	1年以内	本科	互联网	A轮	1000-9999人	06月28日	招聘专员	None
# 2	AI软件工程师	8	16	上海 浦东新区 世纪公园	经验不限	本科	企业服务	A轮	20-99人	06月09日	创始人&产品总监	None
# 2	人工智能研究员	20	30	上海 浦东新区 北蔡	1-3年	本科	移动互联网	B轮	100-499人	09月18日	招聘者	None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in get_subj_alt_name(peer_cert)
#     195     try:
# --> 196         ext = cert.extensions.get_extension_for_class(
#     197             x509.SubjectAlternativeName
#
# /anaconda3/lib/python3.6/site-packages/cryptography/utils.py in inner(instance)
#     160             return cache
# --> 161         result = func(instance)
#     162         setattr(instance, cached_name, result)
#
# /anaconda3/lib/python3.6/site-packages/cryptography/hazmat/backends/openssl/x509.py in extensions(self)
#     137             return _CERTIFICATE_EXTENSION_PARSER_NO_SCT.parse(
# --> 138                 self._backend, self._x509
#     139             )
#
# /anaconda3/lib/python3.6/site-packages/cryptography/hazmat/backends/openssl/decode_asn1.py in parse(self, backend, x509_obj)
#     237
# --> 238                 value = handler(backend, ext_data)
#     239                 extensions.append(x509.Extension(oid, critical, value))
#
# /anaconda3/lib/python3.6/site-packages/cryptography/hazmat/backends/openssl/decode_asn1.py in _decode_key_usage(backend, bit_string)
#     388     key_encipherment = get_bit(bit_string, 2) == 1
# --> 389     data_encipherment = get_bit(bit_string, 3) == 1
#     390     key_agreement = get_bit(bit_string, 4) == 1
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-95aef9b71c82> in <module>()
#      54       #读取每个职位的详细信息页面
#      55       link=item.find('div','info-primary').find('h3').find('a')['href']
# ---> 56       xq=getDetails(link)
#      57       shuchu.append(xq)
#      58       print('\t'.join(shuchu))
#
# <ipython-input-1-95aef9b71c82> in getDetails(link)
#      14 }
#      15 def getDetails(link):
# ---> 16     xq_html=requests.get('https://www.zhipin.com'+link,headers=headers2)
#      17     xq_soup= BeautifulSoup(xq_html.text, 'html.parser')
#      18     miaoshu=''
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     593             is_new_proxy_conn = self.proxy is not None and not getattr(conn, 'sock', None)
#     594             if is_new_proxy_conn:
# --> 595                 self._prepare_proxy(conn)
#     596
#     597             # Make the request on the httplib connection object.
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _prepare_proxy(self, conn)
#     814             set_tunnel(self._proxy_host, self.port, self.proxy_headers)
#     815
# --> 816         conn.connect()
#     817
#     818     def _new_conn(self):
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     335             # the TLS library, this cannot always be done. So we check whether
#     336             # the TLS Library still thinks it's matching hostnames.
# --> 337             cert = self.sock.getpeercert()
#     338             if not cert.get('subjectAltName', ()):
#     339                 warnings.warn((
#
# /anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in getpeercert(self, binary_form)
#     346                 (('commonName', x509.get_subject().CN),),
#     347             ),
# --> 348             'subjectAltName': get_subj_alt_name(x509)
#     349         }
#     350
#
# /anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in get_subj_alt_name(peer_cert)
#     200         # No such extension, return the empty list.
#     201         return []
# --> 202     except (x509.DuplicateExtension, x509.UnsupportedExtension,
#     203             x509.UnsupportedGeneralNameType, UnicodeError) as e:
#     204         # A problem has been found with the quality of the certificate. Assume
#
# AttributeError: module 'cryptography.x509' has no attribute 'UnsupportedExtension'

# %%
url='https://www.lagou.com/gongsi/searchPosition.json'
params={
    'companyId': '94',
    'positionFirstType': '全部',
    'schoolJob': 'true',
    'pageNo': '1',
    'pageSize': '10'
}
headers='''
POST /gongsi/searchPosition.json HTTP/1.1
Host: www.lagou.com
Connection: keep-alive
Origin: https://www.lagou.com
X-Anit-Forge-Code: 38405859
User-Agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36
Content-Type: application/x-www-form-urlencoded; charset=UTF-8
Accept: application/json, text/javascript, */*; q=0.01
X-Requested-With: XMLHttpRequest
X-Anit-Forge-Token: fcd0cae2-af8a-44b7-ae08-6cc103677fc1
Referer: https://www.lagou.com/gongsi/j94.html
Accept-Encoding: gzip, deflate, br
Accept-Language: zh-CN,zh;q=0.9,en;q=0.8,zh-TW;q=0.7
Cookie: JSESSIONID=ABAAABAAAGFABEF8929AE8AEDDF675B0A416152D50F1155; user_trace_token=20180914214240-a2c37a86-ee75-49d4-a447-7d7ec6386510; _ga=GA1.2.764376373.1536932562; LGUID=20180914214241-0d64224c-b824-11e8-b93f-5254005c3644; WEBTJ-ID=20180917170602-165e6c78d78209-0f57b07806360b-3461790f-1296000-165e6c78d7953; __utmc=14951595; __utmz=14951595.1537175176.1.1.utmcsr=m_cf_cpt_sogou_pc|utmccn=(not%20set)|utmcmd=(not%20set); X_HTTP_TOKEN=b53ce1f559f492d4aa675d08bfaa8d93; _putrc=67FE3A6CCEBE7074123F89F2B170EADC; login=true; hasDeliver=0; index_location_city=%E5%85%A8%E5%9B%BD; unick=%E6%8B%89%E5%8B%BE%E7%94%A8%E6%88%B75537; showExpriedIndex=1; showExpriedCompanyHome=1; showExpriedMyPublish=1; Hm_lvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1536932564,1537493466; TG-TRACK-CODE=hpage_code; _gid=GA1.2.969240417.1537831173; gate_login_token=2b25e668e5c92f984fa699aa1142cccd6a9c3d914111e874bf297af1b325c383; __utma=14951595.764376373.1536932562.1537589263.1537831174.12; Hm_lpvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1537831174; LGRID=20180925071933-4b7c4ce8-c050-11e8-bb5c-5254005c3644
'''
jobheaders='''
Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8
Accept-Encoding: gzip, deflate, br
Accept-Language: zh-CN,zh;q=0.9,en;q=0.8,zh-TW;q=0.7
Cache-Control: max-age=0
Connection: keep-alive
Cookie: JSESSIONID=ABAAABAAAGFABEF8929AE8AEDDF675B0A416152D50F1155; user_trace_token=20180914214240-a2c37a86-ee75-49d4-a447-7d7ec6386510; _ga=GA1.2.764376373.1536932562; LGUID=20180914214241-0d64224c-b824-11e8-b93f-5254005c3644; WEBTJ-ID=20180917170602-165e6c78d78209-0f57b07806360b-3461790f-1296000-165e6c78d7953; __utmc=14951595; __utmz=14951595.1537175176.1.1.utmcsr=m_cf_cpt_sogou_pc|utmccn=(not%20set)|utmcmd=(not%20set); X_HTTP_TOKEN=b53ce1f559f492d4aa675d08bfaa8d93; _putrc=67FE3A6CCEBE7074123F89F2B170EADC; login=true; hasDeliver=0; index_location_city=%E5%85%A8%E5%9B%BD; unick=%E6%8B%89%E5%8B%BE%E7%94%A8%E6%88%B75537; showExpriedIndex=1; showExpriedCompanyHome=1; showExpriedMyPublish=1; TG-TRACK-CODE=hpage_code; _gid=GA1.2.496103601.1537969746; gate_login_token=7830c5d476a23bcb03f23c318430bd051e257fbcc2f9bd1e96f850a05b3ae2d6; __utma=14951595.764376373.1536932562.1537831174.1537969747.13; LGSID=20180926222200-88352572-c197-11e8-bb60-5254005c3644; PRE_UTM=; PRE_HOST=localhost; PRE_SITE=http%3A%2F%2Flocalhost%3A8888%2Fnotebooks%2FDesktop%2FJupyterNotebook%2Fspiders%2Flagouwang.ipynb; PRE_LAND=https%3A%2F%2Fwww.lagou.com%2Fjobs%2F5151971.html; LGRID=20180926222222-9554f512-c197-11e8-a6f2-525400f775ce; Hm_lvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1536932564,1537493466,1537971720,1537971743; Hm_lpvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1537971743; __utmb=14951595.5.10.1537969747
Host: www.lagou.com
Referer: https://www.lagou.com/gongsi/j94.html?schoolJob=true
Upgrade-Insecure-Requests: 1
User-Agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36
'''

# %%
def str2obj(s,s1=';',s2='='):
    li=s.split(s1)
    res={}
    for kv in li:
        li2=kv.split(s2)
        if len(li2)>1:
            res[li2[0]]=li2[1]
    return res
headers=str2obj(headers,'\n',': ')
jobheaders=str2obj(jobheaders,'\n',': ')

# %%
import json
import requests
import time
from bs4 import BeautifulSoup

hud=['页数','职位','薪酬','学历','经验','描述']

def getJobs(compId=94,school='true',pageCount=1):
    for i in range(1,1+pageCount):
        params['pageNo']=str(i)
        params['companyId']=compId
        params['schoolJob']=school
        
        params['pageNo']=i
        jsonData=requests.get(url,params=params,headers=headers)
        data=json.loads(jsonData.text)
        #print(json.dumps(data,indent=2,ensure_ascii=False))
        jobs=data['content']['data']['page']['result']
        
        for job in jobs:
            jobli=[str(i)]
            jobli.append(job['positionName'])
            jobli.append(job['salary'])
            jobli.append(job['education'])
            jobli.append(job['workYear'])
            
            #请求二级详情页面
            pid=job['positionId']
            joburl='https://www.lagou.com/jobs/'+str(pid)+'.html'
            jobhtml=requests.get(joburl,headers=jobheaders)
            jobsoup= BeautifulSoup(jobhtml.text, 'html.parser')
            desc=jobsoup.find('dd','job_bt').div.text  
            desc=desc.replace('\n','')
            desc=desc.lstrip().rstrip()
            jobli.append(desc)
            time.sleep(1) 
            
            print('\t'.join(jobli))
        time.sleep(1)

# %%
print('\t'.join(hud))
getJobs(94,'false',5)
# Out:
# 页数	职位	薪酬	学历	经验	描述
# 1	市场部文案策划	10k-20k	本科	不限	职位描述：1、运营公司微信公众号、自媒体平台。2、进行公司企业资料、公告、新闻稿件的撰写工作。3、配合市场活动，策划H5、海报、小程序等传播物料。 任职资格：1、本科及其以上学历，应届毕业生表现优秀者亦可，对科技行业有浓厚兴趣。2、社交媒体深度用户，知乎、微信、微博、豆瓣、简书等皆可，对热点敏感。3、思维敏捷，逻辑清晰，文字表现能力佳。4、最重要的：对工作有责任心。
# 1	商务拓展（商务中心）	8k-16k	大专	不限	岗位职责：1、负责公司智能语音解决方案的销售工作，完成公司制定的销售任务；2、有较强的市场感知能力，敏锐地把握市场动态及方向，分析竞争对手，进行市场拓展；3、开发新客户，维护合作客户，对新客户的完整方案进行规划，挖掘并进行相关管理；4、了解行业相关信息并能充分挖掘客户需求，提供有效的解决方案；5、有人工智能行业从业经验者优先。任职资格：1、全日制统招本科学历，计算机、电子等相关专业；2、三到五年销售工作经验，有云计算、模式识别、芯片原厂相关行业销售经验优先考虑；3、熟悉人工智能语音交互产品的销售流程与运作模式，具备独立开发客户的能力；4、具备良好的团队合作精神，抗压能力强，可适应短期出差。
# 1	商务拓展经理-房地产行业	10k-20k	大专	不限	岗位职责1、负责房地产行业智能语音解决方案的销售工作，完成公司制定的销售任务；2、拓展和开发地产行业客户，针对具体的智能语音应有场景提供解决方案；3、协调和整合内外部资源，跟进和推动解决方案的实施和落地；4、建立和维护行业客户良好合作关系；5、了解行业信息及竞争动态，并能发掘客户需求以提供有效解决方案。任职资格：1、全日制统招本科学历，计算机、电子等相关专业；2、三到五年销售工作经验，有智能家居、地产行业整体解决方案销售经验优先考虑；3、熟悉人工智能语音交互产品的销售流程与运作模式，具备独立开发客户的能力；4、具备良好的团队合作精神，抗压能力强，可适应短期出差；5、有大型房地产客户资源者优先考虑。
# 1	商务拓展经理-酒店行业	10k-20k	大专	不限	岗位职责：1、负责酒店行业智能语音解决方案的销售工作，完成公司制定的销售任务；2、拓展和开发酒店行业客户，针对具体的智能语音应有场景提供解决方案；3、协调和整合内外部资源，跟进和推动解决方案的实施和落地；4、建立和维护行业客户良好合作关系；5、了解行业信息及竞争动态，并能发掘客户需求以提供有效解决方案。任职资格：1、全日制统招本科学历，计算机、电子等相关专业；2、三到五年销售工作经验，有智能家居、酒店行业整体解决方案销售经验优先考虑；3、熟悉人工智能语音交互产品的销售流程与运作模式，具备独立开发客户的能力；4、具备良好的团队合作精神，抗压能力强，可适应短期出差；5、有大型及连锁酒店行业客户资源者优先考虑。
# 1	商务经理（车载行业）	10k-20k	大专	不限	工作内容：1、负责人工智能语音交互产品在车载行业的销售和回款；2、负责新业务产品线的市场开拓，客户潜在需求的深层挖掘；3、负责对竞品的分析与跟踪，制定可执行的销售计划。任职资格：1、全日制统招专科及以上学历，计算机、电子等理工科专业；2、二年以上相关工作经验，熟悉国内车载行业及方案公司；3、熟悉人工智能语音交互产品的销售流程与运作模式，具备独立开发客户的能力；4、具备良好的团队合作精神，抗压能力强，可适应短期出差。
# 1	商务拓展经理-养老行业	10k-20k	大专	不限	岗位职责：1、负责智能养老行业智能语音解决方案的销售工作，完成公司制定的销售任务；2、拓展和开发智能养老行业客户，针对具体的智能语音应有场景提供解决方案；3、协调和整合内外部资源，跟进和推动解决方案的实施和落地；4、建立和维护行业客户良好合作关系；5、研究行业趋势及市场动态，并能发掘客户需求以提供有效解决方案。任职资格：1、全日制统招本科学历，计算机、电子等相关专业；2、三到五年销售工作经验，有智能家居、智能养老设备及方案销售等相关行业工作经验；3、熟悉人工智能语音交互产品的销售流程与运作模式，具备独立开发客户的能力；4、具备良好的团队合作精神，抗压能力强，可适应短期出差；5、有智能养老行业客户资源者优先考虑。
# 1	硬件FAE（商务中心）	8k-16k	本科	1-3年	岗位职责：1、负责人工智能产品一站式技术服务，从方案介绍、立项到量产持续跟进；2、负责项目立项时对客户技术指导，针对语音相关工作进行针对性指导；   3、负责项目推进过程中，对硬件电路、声学结构、阵列驱动进行评审、验证、提交专业报告；4、负责指导项目开发人员对硬件、结构、驱动存在的问题进行修改；5、负责指导工厂进行量产测试，主导制定量产验收标准。     任职要求：1、本科及以上学历，计算机、通信、电子等相关专业；2、有硬件基础，看得懂原理图和PCB图；有硬件开发经验，会使用allegro软件优先考虑；3、有声学结构基础，参与过智能语音产品开发优先考虑；4、对MIC阵列设计，音频信号有过研究优先考虑；5、要求能适应繁琐工作任务，能快速定位问题本质，能自我驱动完成工作目标，良好的沟通和团队协作能力。
# 1	行政主管	8k-13k	大专	5-10年	职位描述：1.公司行政行管制度的制定和执行推动2.负责全公司的日常办公事务管理3.统筹办公物品管理、档案管理、办公室安全卫生等管理协调工作4.统一协调总部及各个分公司的行政事项及行政团队管理5.组织安排员工文娱活动，营造符合企业文化的员工工作环境和氛围6.管理和优化员工关系管理体系，建立和谐、愉快、健康的劳资关系任职要求：1、行政管理、企业管理等相关专业本科以上学历；2、3年以上行政主管工作经验；3、熟悉行政工作流程，办公用品采购流程，企业资产管理；4、较强的责任心和敬业精神，良好的组织协调能力及沟通能力，较强的分析、解决问题能力；5、熟练使用办公软件和办公自动化设备。
# 1	运维技术专家	15k-25k	本科	3-5年	职位描述：工作职责:1、参与运维方向的研发工作, 提高运维自动化水平和效率、故障响应能力、优化资源使用2、参与运维方向的服务架构规划及调整、系统优化及性能分析3、参与运维平台建设，运维相关的新技术研究4、不断优化基础架构，保证在线服务稳定、高效运行任职要求:1. 3年以上互联网服务运维经验2. 工作积极主动,细致踏实,有责任心和良好的团队合作精神3. 学习能力强, 有较强的独立分析和解决问题能力4. 熟悉Linux系统及特性,能根据需求进行系统级优化, 熟悉网络设备的基本配置5. 理解TCP/IP,HTTP协议工作原理,并能进行相关问题或故障的快速定位6. 熟悉Linux下Nginx，Iptables，Haproxy，KeepAlive，Etcd，Redis，Mongodb，Mysql等开源服务和中间件的原理和使用7. 熟悉ELK、Prometheus 或其他类似开源软件的安装,配置和管理,及时快速处理告警8. 熟练使用Shell，并至少掌握Python/Lua/Go等一种或多种语言9. 熟悉Docker,Kubernetes(K8S),有实际生产环境使用及故障处理经验佳
# 1	运维开发工程师	10k-20k	本科	3-5年	1、负责云集群业务运维，保证系统可用性；2、负责对线上系统的性能、可用性进行监控和持续优化；3、持续改善运维流程，参与运维工作标准化、自动化建设；4、持续改进以适应公司业务发展；任职要求:1、工作积极主动,细致踏实,有责任心和良好的团队合作精神；2、学习能力强, 有较强的独立分析和解决问题能力；3、熟悉linux集群涉及到的常用技术以及工作原理,并能进行实际问题或故障的处理；4、熟悉Nginx、Redis、Mongodb、Etcd、RabbitMQ等常见开源软件的配置和优化；5、熟悉ELK、Prometheus 等监控和日志系统者优先6、熟练使用Shell，掌握Python/Go/Lua等一种或多种语言优先7、熟悉或者了解docker，kubernetes者优先
# 2	产品运营	10k-20k	本科	3-5年	-综合利用内容和产品策略等运营手段，提升DUI平台产品用户活跃以及留存。-通过数据分析，结合用户需求，提出产品改进策略并落实推进，提升用户运营数据。-协调内容部门，进行高质量开发者内容的产出，并通过数据反馈，持续改良和优化内容体系。-管理运营部门的产品需求，协调推进运营相关的产品需求.-定期分析竞品的产品/运营动态，为运营和产品提出建议。 任职要求：1. 本科以上学历2. 3年以上相关工作经验；3. 负责过技术平台/开发者相关社区相关产品运营的优先。
# 2	测试开发工程师（Linux /android）	10k-20k	本科	3-5年	职责：1. 参与项目的需求分析，评估需求的可测性和风险。2. 制定测试计划、设计测试方案、编写测试用例。3. 编写Android/Linux等平台上的自动化测试用例，维护自动化测试系统，开发自动化测试工具。4. 负责产品线自动化测试（功能测试/性能测试/回归测试/压力测试/兼容性测试等）相关的技术预研、能力培养和方案落地。要求：1. 本科以上学历，计算机相关专业优先，2. 三年以上测试／开发相关经验。3. 积极主动，有高度责任感，具备很好的沟通能力和团队合作精神；4. 要求有较强编程能力，至少熟悉一种编程语言（C／java／android），至少熟悉一种脚本语言（shell／python／lua）；5. 有自动化测试框架搭建与维护经验者优先。
# 2	服务端测试开发工程师	10k-20k	本科	3-5年	职责：1. 参与项目需求分析，评估需求的可测性和风险；2. 制定测试计划、设计测试方案、编写测试用例；3. 编写Web接口和网页的自动化测试脚本，维护自动化测试系统，开发自动化测试工具；4. 负责产品线自动化测试的相关技术预研、方案落地和能力提升。要求：1. 本科以上学历，计算机相关专业优先；2. 三年以上软件测试或开发相关经验；3. 积极主动，有高度责任感，具备很好的沟通能力和团队合作精神；4. 有较强的编程能力，熟练掌握Java、Python语言中的一种；5. 熟悉Linux操作系统和网络，了解MySQL数据库常用操作和SQL查询；6. 有自动化测试框架搭建与维护经验者优先。
# 2	测试开发工程师/高级测试开发工程师	10k-20k	本科	3-5年	职责：1. 参与项目的需求分析，评估需求的可测性和风险。2. 制定测试计划、设计测试方案、编写测试用例。3. 编写Android/Linux等平台上的自动化测试用例，维护自动化测试系统，开发自动化测试工具。4. 负责产品线自动化测试（功能测试/性能测试/回归测试/压力测试/兼容性测试等）相关的技术预研、能力培养和方案落地。要求：1. 本科以上学历，计算机相关专业优先，2. 三年以上测试／开发相关经验。3. 积极主动，有高度责任感，具备很好的沟通能力和团队合作精神；4. 要求有较强编程能力，至少熟悉一种编程语言（C／java／android），至少熟悉一种脚本语言（shell／python／lua）；5. 有自动化测试框架搭建与维护经验者优先。
# 2	高级BD经理	15k-25k	本科	3-5年	工作职责拓展内容提供商Content Provider，推动优质内容的快速接入拓展服务应用提供商Service Provider，推动各类服务应用的快速接入负责合作项目的方案设计、内外部沟通、信息收集、合同签署等，并跟进执行落地及上线效果维护重点内容和服务提供商，保持长期稳定的合作伙伴关系，并持续挖掘更为深度的合作机会把握市场动向、竞品变化、关注行业生态，发掘新的合作机会职位要求本科及以上学历，2年以上BD相关工作经验具备丰富的移动互联网CP/SP人脉资源，熟悉人工智能领域者优先合作方案撰写能力具备较强的主动学习能力、良好的沟通及资源协调能力、团队合作精神，且抗压能力强有责任感、创新意识，勇于挑战自我Base 北京 or 苏州
# 2	内容BD经理	15k-30k	本科	3-5年	工作职责1.拓展内容提供商Content Provider，推动优质内容的快速接入2.拓展服务应用提供商Service Provider，推动各类服务应用的快速接入3.负责合作项目的方案设计、内外部沟通、信息收集、合同签署等，并跟进执行落地及上线效果4.维护重点内容和服务提供商，保持长期稳定的合作伙伴关系，并持续挖掘更为深度的合作机会5. 把握市场动向、竞品变化、关注行业生态，发掘新的合作机会职位要求1. 本科及以上学历，2年以上BD相关工作经验2. 具备丰富的移动互联网CP/SP人脉资源，熟悉人工智能领域者优先3. 合作方案撰写能力4. 具备较强的主动学习能力、良好的沟通及资源协调能力、团队合作精神，且抗压能力强5. 有责任感、创新意识，勇于挑战自我
# 2	云服务架构师	20k-40k	本科	5-10年	工作职责一起研发连接亿级设备, 亿级用户, 连接车载、家居、IoT、可穿戴、手机等场景的高可用人工智能系统和服务平台负责语音交互云端核心系统的高可用架构设计及相关技术选型负责架构原型实现并推进研发团队完整实现持续改进优化现有服务架构, 不断刷新指标职位要求1.5年以上研发经验, 具有高并发高可用系统架构设计经验2.热爱互联网, 对技术有激情, 喜欢钻研, 有较强的自主学习能力, 能够独立解决问题3.有团队协作精神和沟通能力, 工作认真负责4.熟悉或者精通分布式系统相关理论和实践5.精通TCP/IP网络编程及Http协议, Websocket协议6.熟悉Go语言/OpenResty Lua语言/Nginx优先, 具备快速学习能力7.关注前沿技术, 有自已的开源项目, 或参与优秀开源项目优先
# 2	Java后台开发工程师	10k-20k	大专	3-5年	职位描述：1、参与业务服务后台框架设计和实现；2、根据开发流程进行设计，开发，自测，交付以满足需求；3、能独立处理和解决工作中遇到的问题；4、按要求提交软件开发和测试过程中的各类文档。任职要求：1、计算机相关专业，3年以上Java开发工作经验；2、精通Java的开源框架，如SpringMVC、mybatis、Struts、Ibatis、Hibernate等；3、精通面向对象编程思想和设计模式；4、熟练使用redis、memcache等缓存技术，了解常用的解析框架；5、熟悉多线程、socket、WebService、websocket等技术，熟悉mysql、Mongodb 之类的数据库，并有开发经验；6、熟练使用Linux/UNIX等操作系统，会Python及Lua编程更佳；7、熟悉Oracle、DB2等数据库，并有开发经验；8、性格开朗，积极主动，学习能力强8、责任心强，具备良好的沟通和团队合作精神。
# 2	测试总监	20k-40k	本科	5-10年	岗位职责：1、不断通过测试流程和方法创新, 努力提升测试效率和产品质量；2、参与项目整个过程, 包括需求分析, 设计评审, 用例设计, 评审, 执行, 回归等, 保证产品质量稳定可靠；3.、负责测试团队建设和管理, 测试计划, 流程管理, 绩效考核等。任职要求：1、5年以上测试工作经验, 2年以上团队管理工作经验；2、热爱互联网, 对技术有激情, 喜欢钻研, 有较强的自主学习能力, 能够独立解决问题；3、有团队协作精神和沟通能力, 工作认真负责；4、精通测试理论和项目流程；5、熟悉缺陷管理系统jira；6、有丰富的大型项目测试经验者和项目管理经验
# 2	云服务高级工程师	15k-25k	本科	3-5年	工作职责一起研发连接亿级设备, 亿级用户, 连接车载、家居、IoT、可穿戴、手机等场景的高可用人工智能系统和服务平台参与架构设计和技术选型根据设计完成编码实现, 确保性能, 质量和安全持续升级优化现有服务或组件, 跟踪日志, 修复缺陷职位要求1.3年以上研发经验, 具有高并发高可用系统的经验2.热爱互联网, 对技术有激情, 喜欢钻研, 有较强的自主学习能力, 能够独立解决问题3.有团队协作精神和沟通能力, 工作认真负责4.熟悉TCP/IP网络编程及http协议, Websocket协议5.关注前沿技术, 熟悉分布式高可用网络服务相关理论和实践6.熟悉Go语言/OpenResty Lua语言/Nginx优先, 具备快速学习能力7.关注前沿技术, 有自已的开源项目, 或参与过优秀开源项目更佳
# 3	智能服务核心引擎数据库存储系统高级开发（北京）	26k-40k	本科	5-10年	职位描述：1、NoSQL数据库开发与维护2、图数据库对外查询接口定义与包装实现3、数据库集群的更新，备份，维护以及灾备流程制定 任职要求：1、硕士以上学历，2年以上软件开发工作经验；2、精通数据库原理，可以对数据库内核进行一定的修改       3、熟悉Linux系统，Go语言者优先4、有大规模并发系统开发经验者优先5、有数据库集群管理维护经验者优先
# 3	智能服务核心引擎高级研发经理	40k-60k	硕士	5-10年	岗位职责1、参与智能语音服务系统平台设计和开发，为用户提供高质量的知识理解系统；2、参与NLP/NLU系统的设计和开发，为用户提供高质量文本解析服务3、独立完成JAVA软件设计与开发工作，对代码质量和进度负责；4、负责系统关键模块的设计、开发文档的编写；5、编写和维护单元测试用例；任职要求：1、全日制本科及以上学历，计算机软件或相关专业，3年及以上Java开发经验2、熟练运用Spring等开发框架、面向对象设计、面向对象开发工具，掌握python开发；3、熟悉分布式技术，至少一种消息队列的原理（如activemq，rabbitmq或kafka等），至少一种缓存或NoSQL数据库的设计（如Memcached、Redis、Hbase、Mongodb等），并具有一定优化和问题排查经验。4、熟练使用MySQL数据库进行设计与开发，具有数据库性能调优经验；5、思路清晰，逻辑严谨；6、具有较好的系统架构设计能力，能独立完成方案设计和实施；7、较扎实的计算机基础知识，包括数据结构、算法设计、离散数学等；8、有NLP/NLU方面开发和优化经验。9、具有高质量博客、参与github开源软件开发优先。
# 3	智能服务核心引擎高级研发经理	30k-60k	硕士	5-10年	岗位职责1、参与智能语音服务系统平台设计和开发，为用户提供高质量的知识理解系统；2、参与NLP/NLU系统的设计和开发，为用户提供高质量文本解析服务3、独立完成JAVA软件设计与开发工作，对代码质量和进度负责；4、负责系统关键模块的设计、开发文档的编写；5、编写和维护单元测试用例；任职要求：1、全日制本科及以上学历，计算机软件或相关专业，3年及以上Java开发经验2、熟练运用Spring等开发框架、面向对象设计、面向对象开发工具，掌握python开发；3、熟悉分布式技术，至少一种消息队列的原理（如activemq，rabbitmq或kafka等），至少一种缓存或NoSQL数据库的设计（如Memcached、Redis、Hbase、Mongodb等），并具有一定优化和问题排查经验。4、熟练使用MySQL数据库进行设计与开发，具有数据库性能调优经验；5、思路清晰，逻辑严谨；6、具有较好的系统架构设计能力，能独立完成方案设计和实施；7、较扎实的计算机基础知识，包括数据结构、算法设计、离散数学等；8、有NLP/NLU方面开发和优化经验。9、具有高质量博客、参与github开源软件开发优先。
# 3	智能服务引擎开发工程师	18k-30k	本科	3-5年	岗位职责1、参与智能语音服务系统平台设计和开发，为用户提供高质量的知识理解系统；2、参与NLP/NLU系统的设计和开发，为用户提供高质量文本解析服务3、独立完成JAVA软件设计与开发工作，对代码质量和进度负责；4、负责系统关键模块的设计、开发文档的编写；5、编写和维护单元测试用例；任职要求：1、全日制本科及以上学历，计算机软件或相关专业，3年及以上Java开发经验2、熟练运用Spring等开发框架、面向对象设计、面向对象开发工具，掌握python开发；3、熟悉分布式技术，至少一种消息队列的原理（如activemq，rabbitmq或kafka等），至少一种缓存或NoSQL数据库的设计（如Memcached、Redis、Hbase、Mongodb等），并具有一定优化和问题排查经验。4、熟练使用MySQL数据库进行设计与开发，具有数据库性能调优经验；5、思路清晰，逻辑严谨；6、具有较好的系统架构设计能力，能独立完成方案设计和实施；7、较扎实的计算机基础知识，包括数据结构、算法设计、离散数学等；8、有NLP/NLU方面开发和优化经验。9、具有高质量博客、参与github开源软件开发优先。
# 3	NLP算法研究员	15k-30k	硕士	3-5年	岗位要求：                                                                            1. 熟悉分词、实体识别等NLP工具和算法 2. 熟悉文本相似度计算，文本分类等相关算法3. 数据结构基础扎实，熟练使用至少一种编程语言C/C++, java, python4. 有以下相关经验更好: 对话系统，深度学习，命名实体识别，文本分类5. 两年以上工作经验，硕士及以上学历工作职责：                                                                           负责对话系统中问句理解和意图识别等技术的开发，具体如下：1.研发对话意图分类、意图理解、实体抽取等相关技术2.研发问句检索和排序的相关系统3.开发相似问句挖掘，问句主题分析和问句聚类等相关技术4.追踪NLP前沿技术,并实验转化成产品成果
# 3	NLP对话系统高级开发工程师	20k-40k	本科	3-5年	工作职责：负责对话管理系统和对话平台的研发，具体如下1. 负责通用对话状态管理系统的开发2. 研发对话上下文管理和基于上下文的对话理解3. 构建对话状态的知识体系岗位要求：1. 熟悉基础nlp工具的使用和对话系统原理和流程2. 数据结构基础扎实，熟练使用至少一种编程语言C/C++, java, python3. 两年以上工作经验，本科以上学历。有对话管理系统经验优先
# 3	NLP软件开发工程师/研究科学家 （北京人工智能研发院）	30k-50k	硕士	3-5年	NLP软件开发工程师/研究科学家 （北京研发院） 你想改变人类与计算机进行交互的方式吗？你想要为全世界的用户提供强大的自然用户界面(NUI) 引擎吗？您想要加入到这一项对思必驰很重要的创新技术的研发吗？ 想象一下这个场景， 你可以用语音，手势和你的手机，平板电脑，电视和游戏终端进行交互， 不再需要遥控器，而且你不用绞尽脑汁思考使用什么关键字去搜索你想要的信息，只要对设备里面的个人助手说出你想要完成的事情，它就能智能理解你的意图，给出建议，并且自动帮你完成任务并产生自然的反馈。这一切就如同和一个真人助手交互。 如今计算机的计算能力和存储容量达到前所未有的水平，人类越来越接近自然用户界面的梦想。每一天我们都更接近自然人机交互的目标。为了实现这样的产品，我们需要利用很多语音和语言处理的技术，包括语音识别、 自然语言理解，对话建模、 自然语言生成和语音合成。 思必驰北京研发院正在招聘以下列领域的软件开发工程师和研究科学家。• 自然语言理解和处理。• 机器学习• 机器翻译• 对话建模• 自然语言生成 其他资格包括：1. 拥有计算机硕士/博士学位或相关NUI领域的专业知识2.最少2 年相关领域的工作经验3.有效的沟通和协作能力4.充分了解NUI系统并能做出适当的技术决策5. 擅长软件开发，能够开发高质量的软件6. 熟练掌握脚本，C++ 或 C# ，Python编程语言
# 3	NLP算法高级研究员	20k-40k	本科	3-5年	岗位职责：负责对话系统中问句理解和问答检索等技术的开发，具体如下：1.研发对话意图分类、意图理解、实体消歧等相关技术2.研发问句检索和排序的相关系统3.开发相似问句挖掘，问句主题分析和问句聚类等相关技术4.研究对话生成的相关技术岗位要求1. 熟悉分词、实体识别等NLP工具和算法 2. 熟悉文本相似度计算，文本分类等相关算法3. 数据结构基础扎实，熟练使用至少一种编程语言C/C++, java, python4. 两年以上工作经验，本科以上学历5. 有以下相关经验更好: 对话系统，句法分析，深度学习，实体关系识别
# 3	NLP开发工程师	10k-20k	本科	1-3年	岗位职责：1.    负责对话系统相关数据和知识资源管理流程的开发2.    负责结构化和半结构化数据抽取、大规模知识存储及检索系统的开发和性能优化3.    参与问句检索和意图理解相关的技术开发  任职要求： 1.    本科及以上学历，2年及以上工作经验； 2.    熟悉Java或python开发，熟悉基本数据结构，基础扎实； 3.    有较强的逻辑思维能力，良好的沟通、协作能力； 4.    有大数据分析、爬虫、知识图谱、数据挖掘、自然语言处理等相关经验者优先；熟悉ElasticSearch、Redis等工具的使用优先。 5.    有服务端后端、前端开发经验者有先，熟悉docker者优先
# 3	语音合成高级C/C++ 开发工程师（苏州）	20k-30k	硕士	3-5年	岗位职责：1、语音合成算法或工程研发职位要求：1、本科或者以上学历2、有扎实的工程基础，熟练掌握python或者C++3、有较扎实的机器学习基础，了解深度学习4、有语音合成研发经验优先5、有自然语言处理研发经验优先6、有深度神经网络研发经验优先
# 4	北京研发院高级C/C++开发	20k-40k	硕士	3-5年	岗位职责：1、语音合成算法或工程研发职位要求：1、本科或者以上学历2、有扎实的工程基础，熟练掌握python或者C++3、有较扎实的机器学习基础，了解深度学习4、有语音合成研发经验优先5、有自然语言处理研发经验优先6、有深度神经网络研发经验优先
# 4	北京研发院C/ C++ 资深软件工程师	30k-50k	本科	5-10年	职位描述： 工作内容： 1.负责智能客服的系统架构与设计，进行性能优化及稳定性提升，有充分的产品持续优化的实战经验; 2.负责攻克团队遇到的技术难题， 积极将业界先进技术引入、消化、落地; 3.拆解产品需求，提出技术实现方案和步骤； 4.对负责的系统在业务需求不断的滋养下，通过自己的平台化设计思路，能够不断演进和升级，反哺业务。  任职要求： 1.本科及以上学历，8年及以上相关工作经验；2.有丰富的开发经验及架构设计经验；3.对部分开源技术有深入研究，研究过优秀开源软件的源码并有心得者优先，编程功底扎实，一线编写核心代码；4.精通领域驱动设计，精通设计模式，对于C/C++、对automake autoconf等开发语言以及工具有一定的了解；5.了解UNIMRCP协议、智能服务的机器人领域有相关经验者优先。
# 4	系统架构平台开发工程师-大数据	20k-40k	本科	3-5年	 岗位职责： 1.    设计和实现团队敏捷开发基础流程和平台架构，有迭代以及优化的思想，总结团队可量化的标准和规范； 2.    设计和开发研发团队项目质量保证体系和基础架构； 3.    处理线上和线下日志，实现数据挖掘和展现的基础平台，优化和提升数据价值； 4.    能够整理和分析研发系统平台的系统瓶颈，通过优化平台设计思路，不断演进和升级，提升研发团队的业务能力。 5.    负责攻克团队遇到的技术难题， 积极将业界先进技术引入、消化、落地；  任职要求： 1.    本科及以上学历，2年及以上相关工作经验； 2.    熟悉Java或者python语言，基础扎实； 3.    对分布式系统构建有一定的经验； 4.    对dev-ops模式有相关经验者优先； 5.    有大规模数据挖掘相关经验者优先； 6.    有较强的逻辑思维能力，良好的沟通能力，喜欢挑战，能面对压力。
# 4	北京研发院 高级大数据开发	25k-40k	本科	3-5年	岗位职责： 1.    设计和实现团队敏捷开发基础流程和平台架构，有迭代以及优化的思想，总结团队可量化的标准和规范； 2.    设计和开发研发团队项目质量保证体系和基础架构； 3.    处理线上和线下日志，实现数据挖掘和展现的基础平台，优化和提升数据价值； 4.    能够整理和分析研发系统平台的系统瓶颈，通过优化平台设计思路，不断演进和升级，提升研发团队的业务能力。 5.    负责攻克团队遇到的技术难题， 积极将业界先进技术引入、消化、落地；  任职要求： 1.    本科及以上学历，2年及以上相关工作经验； 2.    熟悉Java或者python语言，基础扎实； 3.    对分布式系统构建有一定的经验； 4.    对dev-ops模式有相关经验者优先； 5.    有大规模数据挖掘相关经验者优先； 6.    有较强的逻辑思维能力，良好的沟通能力，喜欢挑战，能面对压力。
# 4	北京研发院 对话平台JAVA高级开发工程师	20k-40k	本科	3-5年	岗位职责：1.    负责对话系统相关数据和知识资源管理流程的开发2.    负责结构化和半结构化数据抽取、大规模知识存储及检索系统的开发和性能优化3.    参与问句检索和意图理解相关的技术开发  任职要求： 1.    本科及以上学历，2年及以上工作经验； 2.    熟悉Java或python开发，熟悉基本数据结构，基础扎实； 3.    有较强的逻辑思维能力，良好的沟通、协作能力； 4.    有大数据分析、爬虫、知识图谱、数据挖掘、自然语言处理等相关经验者优先；熟悉ElasticSearch、Redis等工具的使用优先。
# 4	高级语音识别工程师（上海）	25k-50k	本科	5-10年	岗位职责1.负责语音识别、信号处理相关算法的研究与开发，如语音信号处理、声学模型训练、语言模型训练、解码器2.负责大数据分析、语音处理相关算法的应用开发及工具编写3.负责语音识别模型训练及新算法应用4.负责支撑产品业务部门的核心技术及模型需求职位要求1.硕士及以上学历，计算机、信号与信息处理、通信工程等相关专业毕业，有3年以上语音识别方向研发经验，有大规模识别模型训练及语音识别全系统搭建经验；2.精通语音识别理论，熟悉声学模型、语言模型或解码器的流程细节，有良好的数学和机器学习理论基础；3.有较强的动手能力，熟悉Lua, Python,Linux SHELL有过相关项目/开发经验, 熟练使用linux系统，具有丰富的编程经验4.具有良好的沟通能力和组织协调能力,具有高度的责任心和执行力，有带团队经验者优先
# 4	高级语音识别工程师（北京）	30k-60k	本科	5-10年	岗位职责1.负责语音识别、信号处理相关算法的研究与开发，如语音信号处理、声学模型训练、语言模型训练、解码器2.负责大数据分析、语音处理相关算法的应用开发及工具编写3.负责语音识别模型训练及新算法应用4.负责支撑产品业务部门的核心技术及模型需求职位要求1.硕士及以上学历，计算机、信号与信息处理、通信工程等相关专业毕业，有3年以上语音识别方向研发经验，有大规模识别模型训练及语音识别全系统搭建经验；2.精通语音识别理论，熟悉声学模型、语言模型或解码器的流程细节，有良好的数学和机器学习理论基础；3.有较强的动手能力，熟悉Lua, Python,Linux SHELL有过相关项目/开发经验, 熟练使用linux系统，具有丰富的编程经验4.具有良好的沟通能力和组织协调能力,具有高度的责任心和执行力，有带团队经验者优先
# 4	语音合成后端高级工程师	20k-40k	本科	3-5年	本岗位至少包含如下一个职责：从事语音合成声学建模研发工作2、从事垂直领域定制合成的效果提升工作3、从事基于深度神经网络的端到端语音合成研发工作4、从事小数据自适应研发工作5、从事声码器改进工作职位要求1、有扎实的工程基础，熟练掌握python或者C++2、有较扎实的机器学习基础，了解深度学习3、熟悉语音合成声学建模原理4、熟悉声码器优先5、熟悉HTS/kaldi优先6、熟悉深度神经网络优先
# 4	语音识别主任研究员	30k-60k	本科	3-5年	语音识别主任研究员岗位职责 1.负责语音识别、信号处理相关算法的研究与开发，如语音前端处理、声学模型训练、语言模型训练、解码器 2.负责大数据分析、语音处理相关算法的应用开发及工具编写 3.负责语音识别模型训练及新算法应用4.负责支撑产品业务部门的核心技术及模型需求职位要求1.硕士及以上学历，计算机、信号与信息处理、通信工程等相关专业毕业，有3年以上语音识别方向研发经验，有大规模识别模型训练及语音识别全系统搭建经验； 2.精通语音识别理论，熟悉声学模型、语言模型或解码器的流程细节，有良好的数学和机器学习理论基础； 3.有较强的动手能力，熟悉Lua, Python,Linux SHELL有过相关项目/开发经验, 熟练使用linux系统，具有丰富的编程经验；4.具有良好的沟通能力和组织协调能力,具有高度的责任心和执行力，有带团队经验者优先；
# 4	语音合成前端高级工程师	20k-40k	本科	3-5年	岗位职责：1、从事基于机器学习的多音字、分词和停顿处理研发工作2、从事文本处理工作，包括文本归一化、录音文本挑选等。职位要求：1、有扎实的工程基础，熟练掌握python或者C++2、有较扎实的机器学习基础，了解深度学习3、有语音合成前端（多音字、分词、停顿预测）经验优先4、有NLP经验优先5、熟悉深度神经网络优先
# 5	自然语言处理工程师	20k-30k	本科	3-5年	职位描述研究自然语言处理领域的前沿技术,问答领域的算法研究负责问答系统工程化实现负责线上及平台问答服务维护和新功能开发    职位要求1. 自然语言处理，模式识别，机器学习, 数据挖掘, 统计以及相关专业硕士以上学历(计算机,电子,通信,自动化)2. 熟悉Lua, Python,Linux SHELL有过相关项目/开发经验, 熟练使用linux系统3. 有自然语言理解和短文本分类工作经验4. 问答系统,人机对话项目经验5. 良好的沟通能力和组织协调能力,优秀的分析问题和解决问题的能力
# 5	高级自然语言处理工程师	20k-40k	硕士	5-10年	职位描述1.研究自然语言处理领域的前沿技术,问答领域的算法研究2.负责问答系统工程化实现3.负责线上及平台问答服务维护和新功能开发职位要求1. 自然语言处理，模式识别，机器学习, 数据挖掘, 统计以及相关专业硕士以上学历(计算机,电子,通信,自动化)2. 熟悉Lua, Python,Linux SHELL有过相关项目/开发经验, 熟练使用linux系统3. 有自然语言理解和短文本分类工作经验4. 问答系统,人机对话项目经验5. 良好的沟通能力和组织协调能力,优秀的分析问题和解决问题的能力
# 5	自然语言处理主任研究员	20k-40k	本科	3-5年	自然语言处理主任研究员岗位职责：1.负责研究自然语言交互相关的核心技术和算法2.负责大数据分析、自然语言处理算法的应用开发及工具编写3.与语音技术团队配合，支撑口语对话系统的业务应用职位要求1.自然语言处理，模式识别，机器学习, 数据挖掘, 统计以及相关专业硕士以上学历(计算机,电子,通信,自动化)，有3年以上自然语言处理工作经验；2.精通自然语言处理的基本算法以及深度学习算法，有大规模真实数据的处理经验，与自然语言理解、问答及对话项目经验者优先；3.熟悉Lua, Python,Linux SHELL有过相关项目/开发经验, 熟练使用linux系统，具有丰富的编程经验；4.具有良好的沟通能力和组织协调能力,具有高度的责任心和执行力，有带团队经验者优先；
# 5	产品经理	10k-20k	本科	3-5年	岗位职责： 1、负责云平台/客户端相关产品规划、需求分析、用户研究等相关工作； 2、分析行业情况，研究竞争对手产品，收集用户需求； 3、负责产品功能设计、流程优化以及交互功能优化； 4、负责产品需求落地，协调各方资源实现产品目标；5、 持续改进产品体验。任职要求：1、本科及以上学历；（211 & 985 & 海外留学背景优先） 2、2年及以上互联网产品规划、设计、运营或相关工作经验； 3、学习能力强、思维活跃，善于把握用户的真正需求，打磨优秀的产品； 4、 对人工智能和语音技术有热情； 5、具备PRD需求文档撰写、产品规划和产品设计能力；6、 持续学习，对人工智能技术能够有持续深入的理解和跟进；7、具有良好的沟通能力和团队精神。
# 5	高级JAVA 服务端开发工程师	20k-40k	本科	3-5年	岗位职责：1.持续对线上系统进行性能优化及稳定性提升;2.负责攻克团队遇到的技术难题， 积极将业界先进技术引入、消化、落地;3.拆解产品需求，提出技术实现方案和步骤；4.对负责的系统在业务需求不断的滋养下，通过自己的平台化设计思路，能够不断演进和升级，反哺业务。任职要求：1.本科及以上学历，3年及以上相关工作经验；2.对于大型复杂分布式互联网后台系统，有丰富的开发经验及架构设计经验JAVA功底扎实，一线编写核心代码；3.对部分JAVA技术有深入研究，研究过优秀开源软件的源码并有心得者优先；4.精通领域驱动设计，精通设计模式；5.精通Mysql数据库，熟悉数据库原理和常用性能优化；6.精通JVM调优，精通NoSql、Queue的原理、使用场景以及限制。
# 5	北京研发院-高级前端开发工程师	20k-40k	本科	5-10年	岗位职责：1.   开发思必驰人工智能语音技术与第三方平台相关的前端内容及服务；2.   开发思必驰人工智能语音技术在微信／钉钉/支付宝等平台的小程序应用及服务；3.   负责思必驰人工智能语音技术在移动端APP产品上落地的前端内容及服务；4.  带领5人以内小型前端团队 任职要求：1.   熟练掌握前端开发的技术中的一项或几项：React / RN / Vue / Node / Electron / ES6 / Angular/ Html5/ CSS等；2.   熟练使用web前端构建工具，了解前端项目模块化解决方案；3.   熟悉MySQL、PostgreSQL、Redis等数据库，具备SQL调优的能力；4.   熟练掌握JavaScript / Python / GoLang一种或几种编程语言，能够合理利用设计模式和模块化的组织方式对代码进行架构；5.   有Linux环境下的开发经验，熟悉基本的Shell脚本；6.   高效的团队协作能力，对各种前端新兴技术有敏锐的洞察力；7.   有很强的责任心，具有较强的分析和解决问题的能力，以及良好的沟通、表达能力

# %%
url='https://www.zhipin.com/c101020100/h_101020100/?query=%E4%BA%BA%E5%B7%A5%E6%99%BA%E8%83%BD&page='
headers={
  'user-agent':'Mozilla/5.0'
}
hud=['页数','职位名','薪资1','薪资2','地点','经验','学历','公司行业','融资阶段','公司人数','发布日期','发布人','详情']
print('\t'.join(hud))

import requests
from bs4 import BeautifulSoup
import time
headers2={
  'user-agent':'Mozilla/5.0',
  'referer':'https://www.zhipin.com/c101020100/h_101020100/'
}
def getDetails(link):
    xq_html=requests.get('https://www.zhipin.com'+link,headers=headers2)
    xq_soup= BeautifulSoup(xq_html.text, 'html.parser')
    miaoshu=''
    try:
        miaoshu=xq_soup.find('div','job-sec').find('div','text').text #获得标记的内部文字
        miaoshu=miaoshu.lstrip().rstrip() #去除开头和结尾的空格
    except:
        miaoshu='None'
    return miaoshu 

for n in range(1,21):  
    html=requests.get(url+str(n),headers=headers)
    soup = BeautifulSoup(html.text, 'html.parser')
    liebiao=soup.find_all('div','job-primary')
    for item in liebiao:
      shuchu=[]
      shuchu.append(str(n))
      shuchu.append(item.find('div','job-title').string) #职位名
      
      xinzi=item.find('span','red').string
      xinzi=xinzi.replace('k','')
      xinzi=xinzi.split('-')
      shuchu.append(xinzi[0]) #薪资起始数
      shuchu.append(xinzi[1]) #薪资起始数
      
      yaoqiu=item.find('p').contents
      shuchu.append(yaoqiu[0].string  if len(yaoqiu)>0 else 'None') #地点
      shuchu.append(yaoqiu[2].string  if len(yaoqiu)>2 else 'None') #经验
      shuchu.append(yaoqiu[4].string  if len(yaoqiu)>4 else 'None') #学历
      
      gongsi=item.find('div','info-company').find('p').contents
      shuchu.append(gongsi[0].string  if len(gongsi)>0 else 'None') #公司行业
      shuchu.append(gongsi[2].string  if len(gongsi)>2 else 'None') #融资阶段
      shuchu.append(gongsi[4].string if len(gongsi)>4 else 'None') #公司人数
      
      shuchu.append(item.find('div','info-publis').find('p').string.replace('发布于','')) #发布日期
      shuchu.append(item.find('div','info-publis').find('h3').contents[3].string) #发布人
      
      #读取每个职位的详细信息页面
      link=item.find('div','info-primary').find('h3').find('a')['href']
      xq=getDetails(link)
      shuchu.append(xq)      
      print('\t'.join(shuchu))
      time.sleep(0.2)
# Out:
# 页数	职位名	薪资1	薪资2	地点	经验	学历	公司行业	融资阶段	公司人数	发布日期	发布人	详情
# 10	AI语音智能机器人优化工程师	4	6	上海  	经验不限	学历不限	通信/网络设备	未融资	20-99人	05月16日	副总经理	1、专职负责公司的AI语音智能机器人客户的话术脚本的形成和上线后机器人的话术训练和优化工作；2、工作内容包括：1）指定行业、指定业务的专业知识收集、整理和学习；2）同签约项目公司的业务人员沟通交流形成指定业务或是项目的AI语音智能机器人话术脚本。3）收集整理AI语音智能机器人上线后的问题，不断训练和优化AI语音智能机器人的话术脚本，让机器人变得越来越聪明和专业。
# 10	大数据人工智能工程师 - 深度学习方向	25	35	上海 虹口区 七浦路	1-3年	本科	互联网	不需要融资	500-999人	04月12日	人力资源	岗位职责：负责构建人工智能平台，并以实际业务应用为导向研发创新方法，产生创新应用任职要求：1. 本科以上学历（模式识别、人工智能、计算机相关专业），扎实的机器学习、数据挖掘、统计学理论基础；2. 精通至少一种深度学习开源框架（Caffe, Tensorflow, PyTorch，MXNet等），具有实际开发经验者优先3. 具有扎实的计算机操作系统、数据结构等编程基础，精通至少一门编程语言例如JAVA/Python/Scala等，编程能力扎实；4. 在图像处理, 语音识别, 自然语言处理等领域有深入研究或实际项目经验者优先5. 具有开源工作经验者优先
# 10	AI工程师	15	20	上海 黄浦区 南京东路	1年以内	本科	智能硬件	0-20人	None	07月15日	CTO	1. 熟练使用计算机视觉和深度学习算法进行图像识别、检测等软件的开发；2. 熟练使用GMM-HMM和深度学习算法进行语音识别软件的开发；3. 模型训练和效果调优。任职资格：1. 坚实的计算机基础与广泛的数学知识；2. 过硬的代码能力，扎实掌握C/C++和/或python语言；3. 对人工智能有充分的好奇心和探索欲；4. 加分项：有计算机视觉或深度学习经验；了解计算硬件和体系结构；ACM或OI编程竞赛经历
# 10	AI算法工程师	16	20	上海 嘉定区 	3-5年	本科	计算机软件	B轮	1000-9999人	05月18日	招聘主管	1.	会SQL, 了解数据库基本知识2.	会Python 或 R 编程3.	统计和基本的机器学习算法4.	掌握数据可视化5.	能用英语交流数据分析的业务（听，说，写)6.	2年左右的工作经验7.	有机电制造业背景更佳有班车 有班车 有班车 浦东  杨浦 大华 人民广场 莘庄均有班车
# 10	人工智能算法工程师兼职讲师	20	30	上海 浦东新区 陆家嘴	经验不限	本科	在线教育	C轮	100-499人	03月08日	人事	人工智能算法工程师上海职位信息岗位职责：1、负责智能人机交互包括语音合成、语音识别、手势识别、自然语言处理、情绪识别、人脸识别、图像处理等技术研发；2、参与核心代码的书写，组织解决项目开发过程中的重大技术问题；3、对人工智能技术的研究，包括机器学习、智能控制、知识应用、智能决策等技术的研究；4、负责人工智能技术的应用研究开发。5、按照北风需求把课程录制成视频。任职要求：1、2-3年人工智能及机器学习开发经验2、精通TensorFlow等人工智能开发框架，有实际经验3、精通开发语言Python4、熟悉机器学习各种算法，包括聚类、分类、推荐、回归等算法5、具有良好的沟通能力和协调能力，技术跟踪和创新能力，良好的团队精神，能承受工作压力，富有进取心。
# 10	人工智能课程讲师	4	8	上海 青浦区 徐泾	经验不限	学历不限	在线教育	不需要融资	100-499人	07月06日	招聘者	一、职位特点：1、线上网络授课（直播或录播），工作地点不限。2、记薪方式为时薪，据资质每时300-600元。二、能力要求1、国内外高校人工智能技术、人工智能领域的硕士、博士、专家、学者等。三、经验要求1、有相关理论、应用文章或著作发表者优先2、有线上、线下的讲师、培训讲师经历的为佳。
# 10	人工智能	25	50	上海 普陀区 金沙江路	3-5年	本科	互联网	已上市	10000人以上	06月13日	招聘者	岗位职责：1. 负责大数据相关应用算法的设计、研发与产品化；2. 负责挖掘海量商品模型图片，提供风格识别，材质识别，图片搜索，个性推荐等功能；3. 负责挖掘海量设计方案，提供风格识别、智能搜索、个性化推荐等功能；4. 负责挖掘海量户型图，提供相似户型、修改户型方案、智能搜索等功能；5. 负责室内设计智能算法的研发，根据用户特征，提供样板间自动匹配和方案自动生成等功能。         任职资格：1. 计算机科学与技术或相关专业学士学位，硕士、博士学位更佳；2. 在个性化推荐、数据挖掘、机器学习等领域中有相关工作经验；3. 对决策树、逻辑回归、支持向量机，贝叶斯方法、降维，聚类，人工神经网络相关的算法均有所了解，并至少对一种有实际应用经验；4. 对大数据计算平台相关的技术比较深入了解，并有实际应用经验。
# 10	大数据和人工智能后台开发	20	35	上海 徐汇区 田林	5-10年	本科	互联网	已上市	10000人以上	07月19日	hr	岗位要求：1精通Linux和C/C++、PHP/Python、Java等一种或几种编程语言；2 至少5年以上技术开发相关工作经验；3 熟悉研发管理和质量管理流程，有云计算产品或SaaS服务交付经验； 4能独立完成模块开发和交付工作；5 有高并发、大容量后台服务设计经验； 6熟悉云计算及大数据相关技术；7 有大数据、机器学习，图片识别、语音识别中至少一种相关背景和经验；8 有新一代应用设计、开发和运维经验，例如Container、Kubernetes 、DevOps、CD/CI等；9 具备良好的沟通表能力及团队协作精神、有较强的主动性、责任心与执行能力； 10本科或以上计算机相关专业。岗位职责：1负责大数据和AI商业化产品的研发和交付； 2了解客户需求，按期保质完成研发计划；3 协助解决方案团队，完成客户化方案的实施；4 协助运维团队，保障已交付产品的运营和服务。
# 10	人工智能老师	11	13	上海 静安区 共和新路	1年以内	本科	在线教育	0-20人	None	01月14日	CEO	了解ai基本算法，了解机器学习和深度学习等，做过项目最优。此职位有兼职有全职，包住。在项目制培训中老师也可以接触到最前沿的真实企业项目，和学生一起提高。薪资从优
# 10	AI专家（NLP）	40	60	上海 徐汇区 枫林路	5-10年	硕士	企业服务	20-99人	None	06月07日	招聘者	AI专家（NLP方向）岗位职责：1. 医疗领域的自然语言处理，包括分词、词性标注、命名实体识别、浅层句法分析、依层语法分析2. 文本数据的向量数、数值化，语义相似度的计算，包括词、短语及整句的级别3. 文本数据中的关键信息抽取，包括问答对中的提问和回答的关键信息4. 医疗领域的数据挖掘，包括方案设计、数据模型设计、数据的标准化、数据质量的保证5. 医疗决策支持系统的模型（知识图谱）和推理引擎的开发，包括方案设计、分类或回归模型的创建、调优、上线6. 知识图谱驱动的聊天机器人开发，通过对话完成数据收集，问题的生成及回答的自然语言理解职责要求：1. 拥有自然语言处理、机器学习、模式识别、人工智能等相关专业的硕士、博士2. 拥有较为丰富的自然语言处理、知识图谱、机器学习、深度学习方面的项目经验3. 熟悉常用机器学习算法，熟悉深度学习算法4. 工程实现能力强，能够胜任包括数据清洗、原型实现、训练调优、线上算法各个阶段的研发任务5. 思路清晰，表达能力强；良好的团队合作精神
# 10	平面设计师	6	10	上海 奉贤区 南桥	经验不限	大专	广告/公关/会展	0-20人	None	09月14日	招聘者	熟练使用AI或PS等设计软件，对色彩感觉好，有广告从业经验者优先！
# 10	设计师助理	5	9	上海 闵行区 航华	经验不限	本科	广告营销	不需要融资	0-20人	06月02日	設計总監	Ai與Ps為基礎，擅長手繪。善于學習、思維敏捷。適應高強度工作。方向培養：設計組長。
# 10	广告设计师	5	6	上海  	3-5年	本科	广告营销	不需要融资	0-20人	04月24日	招聘者	对设计有抱负，熟练AI 和PS , 热情和坚持，勤奋上进，有好学心，敢于担当，负责.
# 10	Java开发工程师(AI产品方向)	18	35	上海 浦东新区 八佰伴	经验不限	本科	计算机软件	不需要融资	1000-9999人	07月26日	招聘者	岗位职责：在ai人工智能团队负责大数据产品的研发实现。岗位要求：211及以上院校本科以上学历，三年以上互联网或者金融相关行业java开发经验（此岗位是否做过人工智能产品开发没有强制要求，但学历背景一定要好一些，这样入职以后资深的同事带起来会快一些）。
# 10	AI工程师-知识图谱	15	30	上海 徐汇区 	1-3年	硕士	互联网	C轮	100-499人	09月28日	招聘经理	岗位职责：1.负责知识图谱的存储与管理。2.负责基于知识图谱的高效查询与挖掘分析。3.负责知识图谱构建、推理及相关应用研发工作。任职要求：1.精通Python、Java中的至少一种；2.有neo4j图数据库设计、管理、优化经验，掌握MongoDB技术；3.了解自然语言处理；4.有知识图谱领域工作经验者优先；5.计算机相关专业本科及以上学历。
# 10	AI项目研发／架构工程师	30	45	上海 浦东新区 八佰伴	5-10年	本科	计算机软件	B轮	100-499人	07月09日	HR	工作职责：1.负责AI客户项目的系统设计和开发工作，协助AI科学家将AI能力应用到实际客户中去2.深入理解公司的AI产品——先知平台，并对平台进行改进、扩展，以服务更多的应用场景3.- 研究相关新技术，并努力提升项目研发的效率和质量任职要求：1.认同并坚信人工智能能为产业带来革命性的变化，对未知的渴求2.统招本科及以上学历，计算机、软件或相关专业3.2年或以上（应届生除外）的后端开发经验，并具有扎实的代码功底和实战能力4.熟练掌握java、python、shell语言及其生态圈5.熟悉Linux操作系统及其环境中的开发模式6.熟悉常用的数据库技术，了解常用的各类开源框架、组件或中间件7.熟悉Hadoop技术及其生态圈(Spark等)8.工作踏实、积极，责任心强，能承担压力，有较强的执行力、解决复杂问题能力和自我驱动能力9.良好的沟通能力和团队协作能力加分项：1.	有前端研发经验者优先2.	有架构经验，系统优化经验者优先3.	熟悉金融、银行类项目者优先
# 10	美工	5	8	上海 普陀区 中远两湾城	1年以内	学历不限	广告营销	天使轮	0-20人	05月11日	总经理	*熟练使用AI、PS等adobe软件进行设计与排版。*独立创意构思，设计出街的商业海报、包装等。*独立完成设计衍生应用，材质建议与制作完稿。*熟悉活动项目现场搭建，熟悉尺寸材质等优先。
# 10	图像识别	20	30	上海 徐汇区 漕河泾	3-5年	本科	在线教育	B轮	500-999人	03月14日	CPO	人工智能相关
# 10	平面设计师	5	8	上海 嘉定区 马陆	1-3年	大专	广告/公关/会展	0-20人	None	08月22日	招聘者	熟练运用Photoshop、AI、CorelDRAW等平面设计软件。有责任心。做5休2。
# 10	人工智能产品介绍	5	6	上海 闵行区 莘庄	经验不限	大专	智能硬件	A轮	20-99人	06月02日	市场总监	儿童乐园人工智能摄影机器人产品推广在这里你不仅可以赚钱，而且可以学习最前沿高科技的人工智能摄影机器人的相关知识。工作内容：1.180元每天，月结工资，主要是对人工智能摄影产品进行介绍。2.引导家长扫码微信小程序注册。3.派单等现场执行工作。工作时间：上午场9:30-14:00、下午场15:30-19:30可以做半天。工作要求：1.介绍产品语言表达能力强，不可迟到早退。2.热情主动有活力勤快。3.有做过销售类工作优先，周一到周五可以持续做的优先。4.18-25岁在校大学生优先，可以做实习生。（有学生证）
# 10	高级/资深智能问答算法工程师	18	30	上海 长宁区 北新泾	1-3年	本科	互联网	已上市	10000人以上	09月16日	算法高级经理	携程CEO大奖核心团队招聘15薪 带薪年假 AI团队职位描述：   1. 负责智能问答（QA）的算法研究与引擎设计开发；    2. 负责跟进行业前沿技术发展趋势，跟踪国际最新算法发展方向和相应技术。任职资格：   1. 毕业于统招硕士以上学历，计算机相关专业；   2. 了解当前智能问答的方法，能够跟踪最新的研究方向；   3. 了解智能问答的相关背景知识；   4. 至少掌握一门编程语言，有一定的软件开发项目经验（精通C/C++优先）；   5. 能够流畅阅读英文文献   6. 有相关工作经历或实验室背景优先；   7. 有LR/GMM/SVM/CRF/MaxEnt/HMM/LDA/DNN/CNN/RNN的研究背景者优先；   8. 能够在TensorFlow/Torch/Theano/Keras/Mxnet/Currennt上开展实验者优先；   9.能够对智能问答（QA）算法进行工程实现和优化。
# 10	C++开发工程师（人工智能方向）	18	36	上海 浦东新区 八佰伴	1-3年	硕士	计算机软件	不需要融资	1000-9999人	08月27日	招聘者	岗位职责：负责人工智能条线智能识别相关技术研究与开发，并把研究成果应用于相关智能识别产品。岗位要求：1、硕士研究生及以上学历，计算机相关专业；2、熟悉C++和python；备注：该岗位无需人工智能方面的工作经验，但学习能力一定要强，入职以后会有专人带教学习人工智能相关的算法，这样的话上手会比较快一些。
# 10	平面设计师	5	8	上海 长宁区 镇宁路	1年以内	大专	电子商务	不需要融资	100-499人	10月20日	总经理	图软件：Coreldraw、Photoshop、Illustrator、AI等；2、有较好的眼光和审美能力，对色彩敏感，领悟性高，具有创造力、想象力；3、能独立完成画册、海报等设计；4、积极主动，赋有沟通协作精神。任职资格：1、精通Coreldraw、Photoshop、Illustrator、AI等设计软件；2、具备良好的设计创意和美工基础，能够快速、准确领会设计意图；3、大专及以上学历，美术、平面设计或相关专业毕业，至少一年以上的平面设计和制作经验；有大型B2B、B2C知名电子商务网站设计工作经验者优先；4、沟通表达能力强，能够与各相关部门进行积极、主动、有效的沟通。
# 10	婚礼设计	4	6	上海 静安区 和田	1年以内	大专	婚庆/摄影	未融资	20-99人	09月15日	招聘者	根据新人要求与喜好，并按场地实际情况，为新人提供合理且富有创意的设计方案。
# 10	广告展览设计师	6	12	上海 闵行区 春申	经验不限	学历不限	广告/公关/会展	未融资	0-20人	08月19日	总经理	熟练掌握展览设计软件 3Dmax ps Ai等，我司属于中高端展览设计搭建一体化公司，目前公司业务分别在美国 德国 日本 新加坡 泰国等地.我们公司的设计图格调较国际化 简洁 精致，在上海经常同一些排名行业前列的公司的pk.  其次我们对于项目会进行严格筛选，大多是优质客户所以无论你是初级还是中高级设计师，我们公司都是很好的平台. 期待你的加入. 谢谢.
# 10	产品设计师	5	6	上海 浦东新区 金桥	1年以内	大专	电子商务	未融资	20-99人	09月14日	人事	PS,CDR或者AI,CAD,会3D更好做五休二，早九晚五每年一月统一涨薪
# 10	高级Android开发工程师（AI产品）	20	40	上海 徐汇区 虹梅路	3-5年	本科	互联网	D轮及以上	100-499人	07月11日	招聘者	岗位职责：1. 负责海外AI产品Android平台客户端软件，调研、开发、维护工作；2. 对Android平台开发技术进行研究，定位和解决一些技术疑难问题；3. 按照项目计划，按时提交高质量的代码，完成开发任务；4. 改善软件的易用性，提升用户使用体验；5. 规范和文档的编写、维护。任职要求：1. 3年及以上Android开发经验，本科及以上学历；2. 熟悉Android框架及各种特性，精通客户端程序设计方法，具备扎实的Java编程基础；3. 熟练掌握Git，熟练掌握Android Studio开发工具及各种性能调优；4. 至少具备一到两个成熟的应用项目，有过上架或正式交付使用的作品。能独立研发App，或者带领团队研发；5. 具备良好的代码风格、注释风格，具有一定的软件技术文档编写能力，包括但不限于调研需求、需求分析、SDK使用等；6. 有前端JavaScript，HTML5，iOS，Python开发经验者优先；7. 有海外开发经验及Google Play发布经验者优先，有对接广告平台经验者优先（包括但不限于Google Play，Facebook等）；8. 抗压能力强，具有良好的团队合作意识，时间观念强。
# 10	项目工程师	10	20	上海 普陀区 金沙江路	1-3年	本科	计算机软件	0-20人	None	09月17日	招聘者	完善人工智能病理阅片系统，配合上海交大医学图像实验室完善
# 10	ocr算法专家（上海）	25	40	上海  	5-10年	本科	企业服务	已上市	100-499人	06月10日	高级副总裁	精通ocr识别算法，有相关经验熟悉票据识别处理能独立完成算法实现
# 10	图像算法	12	20	上海 静安区 共和新路	经验不限	本科	医疗健康	已上市	1000-9999人	08月28日	招聘者	人工智能（深度学习算法工程师）（上海） 岗位职责：1.开发基于医学影像的深度学习、机器学习算法和应用，在医学影像领域落地并产生实际价值，提升用户的的工作效率2.同客户合作，进行基于临床场景的的算法模型转化3.基于数据驱动的工作模式，追踪工业界与学术界的相关进展，不断尝试把新技术引入到现有系统和构建新系统；岗位要求： 1）1.电子工程、计算机科学/工程或相关领域的硕士/博士学位。2.掌握计算机视觉领域的基础理论和方法3.有深度学习和医学成像方面的深厚实践经验者优先4.有快速的开发模型的技巧，特别是用Python开发医疗成像应用的经验。5.精通深度学习框架（caffe、Mxnet、Tensorflow、pytorch，等）。6.在医学成像和计算机视觉等应用领域有丰富经验者优先；7.医学影像可视化和处理经验者优先。
# 11	AI语音智能机器人优化工程师	4	6	上海  	经验不限	学历不限	通信/网络设备	未融资	20-99人	05月16日	副总经理	1、专职负责公司的AI语音智能机器人客户的话术脚本的形成和上线后机器人的话术训练和优化工作；2、工作内容包括：1）指定行业、指定业务的专业知识收集、整理和学习；2）同签约项目公司的业务人员沟通交流形成指定业务或是项目的AI语音智能机器人话术脚本。3）收集整理AI语音智能机器人上线后的问题，不断训练和优化AI语音智能机器人的话术脚本，让机器人变得越来越聪明和专业。
# 11	大数据人工智能工程师 - 深度学习方向	25	35	上海 虹口区 七浦路	1-3年	本科	互联网	不需要融资	500-999人	04月12日	人力资源	岗位职责：负责构建人工智能平台，并以实际业务应用为导向研发创新方法，产生创新应用任职要求：1. 本科以上学历（模式识别、人工智能、计算机相关专业），扎实的机器学习、数据挖掘、统计学理论基础；2. 精通至少一种深度学习开源框架（Caffe, Tensorflow, PyTorch，MXNet等），具有实际开发经验者优先3. 具有扎实的计算机操作系统、数据结构等编程基础，精通至少一门编程语言例如JAVA/Python/Scala等，编程能力扎实；4. 在图像处理, 语音识别, 自然语言处理等领域有深入研究或实际项目经验者优先5. 具有开源工作经验者优先
# 11	AI工程师	15	20	上海 黄浦区 南京东路	1年以内	本科	智能硬件	0-20人	None	07月15日	CTO	1. 熟练使用计算机视觉和深度学习算法进行图像识别、检测等软件的开发；2. 熟练使用GMM-HMM和深度学习算法进行语音识别软件的开发；3. 模型训练和效果调优。任职资格：1. 坚实的计算机基础与广泛的数学知识；2. 过硬的代码能力，扎实掌握C/C++和/或python语言；3. 对人工智能有充分的好奇心和探索欲；4. 加分项：有计算机视觉或深度学习经验；了解计算硬件和体系结构；ACM或OI编程竞赛经历
# 11	AI算法工程师	16	20	上海 嘉定区 	3-5年	本科	计算机软件	B轮	1000-9999人	05月18日	招聘主管	1.	会SQL, 了解数据库基本知识2.	会Python 或 R 编程3.	统计和基本的机器学习算法4.	掌握数据可视化5.	能用英语交流数据分析的业务（听，说，写)6.	2年左右的工作经验7.	有机电制造业背景更佳有班车 有班车 有班车 浦东  杨浦 大华 人民广场 莘庄均有班车
# 11	人工智能算法工程师兼职讲师	20	30	上海 浦东新区 陆家嘴	经验不限	本科	在线教育	C轮	100-499人	03月08日	人事	人工智能算法工程师上海职位信息岗位职责：1、负责智能人机交互包括语音合成、语音识别、手势识别、自然语言处理、情绪识别、人脸识别、图像处理等技术研发；2、参与核心代码的书写，组织解决项目开发过程中的重大技术问题；3、对人工智能技术的研究，包括机器学习、智能控制、知识应用、智能决策等技术的研究；4、负责人工智能技术的应用研究开发。5、按照北风需求把课程录制成视频。任职要求：1、2-3年人工智能及机器学习开发经验2、精通TensorFlow等人工智能开发框架，有实际经验3、精通开发语言Python4、熟悉机器学习各种算法，包括聚类、分类、推荐、回归等算法5、具有良好的沟通能力和协调能力，技术跟踪和创新能力，良好的团队精神，能承受工作压力，富有进取心。
# 11	人工智能课程讲师	4	8	上海 青浦区 徐泾	经验不限	学历不限	在线教育	不需要融资	100-499人	07月06日	招聘者	一、职位特点：1、线上网络授课（直播或录播），工作地点不限。2、记薪方式为时薪，据资质每时300-600元。二、能力要求1、国内外高校人工智能技术、人工智能领域的硕士、博士、专家、学者等。三、经验要求1、有相关理论、应用文章或著作发表者优先2、有线上、线下的讲师、培训讲师经历的为佳。
# 11	人工智能	25	50	上海 普陀区 金沙江路	3-5年	本科	互联网	已上市	10000人以上	06月13日	招聘者	岗位职责：1. 负责大数据相关应用算法的设计、研发与产品化；2. 负责挖掘海量商品模型图片，提供风格识别，材质识别，图片搜索，个性推荐等功能；3. 负责挖掘海量设计方案，提供风格识别、智能搜索、个性化推荐等功能；4. 负责挖掘海量户型图，提供相似户型、修改户型方案、智能搜索等功能；5. 负责室内设计智能算法的研发，根据用户特征，提供样板间自动匹配和方案自动生成等功能。         任职资格：1. 计算机科学与技术或相关专业学士学位，硕士、博士学位更佳；2. 在个性化推荐、数据挖掘、机器学习等领域中有相关工作经验；3. 对决策树、逻辑回归、支持向量机，贝叶斯方法、降维，聚类，人工神经网络相关的算法均有所了解，并至少对一种有实际应用经验；4. 对大数据计算平台相关的技术比较深入了解，并有实际应用经验。
# 11	大数据和人工智能后台开发	20	35	上海 徐汇区 田林	5-10年	本科	互联网	已上市	10000人以上	07月19日	hr	岗位要求：1精通Linux和C/C++、PHP/Python、Java等一种或几种编程语言；2 至少5年以上技术开发相关工作经验；3 熟悉研发管理和质量管理流程，有云计算产品或SaaS服务交付经验； 4能独立完成模块开发和交付工作；5 有高并发、大容量后台服务设计经验； 6熟悉云计算及大数据相关技术；7 有大数据、机器学习，图片识别、语音识别中至少一种相关背景和经验；8 有新一代应用设计、开发和运维经验，例如Container、Kubernetes 、DevOps、CD/CI等；9 具备良好的沟通表能力及团队协作精神、有较强的主动性、责任心与执行能力； 10本科或以上计算机相关专业。岗位职责：1负责大数据和AI商业化产品的研发和交付； 2了解客户需求，按期保质完成研发计划；3 协助解决方案团队，完成客户化方案的实施；4 协助运维团队，保障已交付产品的运营和服务。
# 11	人工智能老师	11	13	上海 静安区 共和新路	1年以内	本科	在线教育	0-20人	None	01月14日	CEO	了解ai基本算法，了解机器学习和深度学习等，做过项目最优。此职位有兼职有全职，包住。在项目制培训中老师也可以接触到最前沿的真实企业项目，和学生一起提高。薪资从优
# 11	AI专家（NLP）	40	60	上海 徐汇区 枫林路	5-10年	硕士	企业服务	20-99人	None	06月07日	招聘者	AI专家（NLP方向）岗位职责：1. 医疗领域的自然语言处理，包括分词、词性标注、命名实体识别、浅层句法分析、依层语法分析2. 文本数据的向量数、数值化，语义相似度的计算，包括词、短语及整句的级别3. 文本数据中的关键信息抽取，包括问答对中的提问和回答的关键信息4. 医疗领域的数据挖掘，包括方案设计、数据模型设计、数据的标准化、数据质量的保证5. 医疗决策支持系统的模型（知识图谱）和推理引擎的开发，包括方案设计、分类或回归模型的创建、调优、上线6. 知识图谱驱动的聊天机器人开发，通过对话完成数据收集，问题的生成及回答的自然语言理解职责要求：1. 拥有自然语言处理、机器学习、模式识别、人工智能等相关专业的硕士、博士2. 拥有较为丰富的自然语言处理、知识图谱、机器学习、深度学习方面的项目经验3. 熟悉常用机器学习算法，熟悉深度学习算法4. 工程实现能力强，能够胜任包括数据清洗、原型实现、训练调优、线上算法各个阶段的研发任务5. 思路清晰，表达能力强；良好的团队合作精神
# 11	平面设计师	6	10	上海 奉贤区 南桥	经验不限	大专	广告/公关/会展	0-20人	None	09月14日	招聘者	熟练使用AI或PS等设计软件，对色彩感觉好，有广告从业经验者优先！
# 11	设计师助理	5	9	上海 闵行区 航华	经验不限	本科	广告营销	不需要融资	0-20人	06月02日	設計总監	Ai與Ps為基礎，擅長手繪。善于學習、思維敏捷。適應高強度工作。方向培養：設計組長。
# 11	广告设计师	5	6	上海  	3-5年	本科	广告营销	不需要融资	0-20人	04月24日	招聘者	对设计有抱负，熟练AI 和PS , 热情和坚持，勤奋上进，有好学心，敢于担当，负责.
# 11	Java开发工程师(AI产品方向)	18	35	上海 浦东新区 八佰伴	经验不限	本科	计算机软件	不需要融资	1000-9999人	07月26日	招聘者	岗位职责：在ai人工智能团队负责大数据产品的研发实现。岗位要求：211及以上院校本科以上学历，三年以上互联网或者金融相关行业java开发经验（此岗位是否做过人工智能产品开发没有强制要求，但学历背景一定要好一些，这样入职以后资深的同事带起来会快一些）。
# 11	AI工程师-知识图谱	15	30	上海 徐汇区 	1-3年	硕士	互联网	C轮	100-499人	09月28日	招聘经理	岗位职责：1.负责知识图谱的存储与管理。2.负责基于知识图谱的高效查询与挖掘分析。3.负责知识图谱构建、推理及相关应用研发工作。任职要求：1.精通Python、Java中的至少一种；2.有neo4j图数据库设计、管理、优化经验，掌握MongoDB技术；3.了解自然语言处理；4.有知识图谱领域工作经验者优先；5.计算机相关专业本科及以上学历。
# 11	AI项目研发／架构工程师	30	45	上海 浦东新区 八佰伴	5-10年	本科	计算机软件	B轮	100-499人	07月09日	HR	工作职责：1.负责AI客户项目的系统设计和开发工作，协助AI科学家将AI能力应用到实际客户中去2.深入理解公司的AI产品——先知平台，并对平台进行改进、扩展，以服务更多的应用场景3.- 研究相关新技术，并努力提升项目研发的效率和质量任职要求：1.认同并坚信人工智能能为产业带来革命性的变化，对未知的渴求2.统招本科及以上学历，计算机、软件或相关专业3.2年或以上（应届生除外）的后端开发经验，并具有扎实的代码功底和实战能力4.熟练掌握java、python、shell语言及其生态圈5.熟悉Linux操作系统及其环境中的开发模式6.熟悉常用的数据库技术，了解常用的各类开源框架、组件或中间件7.熟悉Hadoop技术及其生态圈(Spark等)8.工作踏实、积极，责任心强，能承担压力，有较强的执行力、解决复杂问题能力和自我驱动能力9.良好的沟通能力和团队协作能力加分项：1.	有前端研发经验者优先2.	有架构经验，系统优化经验者优先3.	熟悉金融、银行类项目者优先
# 11	美工	5	8	上海 普陀区 中远两湾城	1年以内	学历不限	广告营销	天使轮	0-20人	05月11日	总经理	*熟练使用AI、PS等adobe软件进行设计与排版。*独立创意构思，设计出街的商业海报、包装等。*独立完成设计衍生应用，材质建议与制作完稿。*熟悉活动项目现场搭建，熟悉尺寸材质等优先。
# 11	图像识别	20	30	上海 徐汇区 漕河泾	3-5年	本科	在线教育	B轮	500-999人	03月14日	CPO	人工智能相关
# 11	平面设计师	5	8	上海 嘉定区 马陆	1-3年	大专	广告/公关/会展	0-20人	None	08月22日	招聘者	熟练运用Photoshop、AI、CorelDRAW等平面设计软件。有责任心。做5休2。
# 11	人工智能产品介绍	5	6	上海 闵行区 莘庄	经验不限	大专	智能硬件	A轮	20-99人	06月02日	市场总监	儿童乐园人工智能摄影机器人产品推广在这里你不仅可以赚钱，而且可以学习最前沿高科技的人工智能摄影机器人的相关知识。工作内容：1.180元每天，月结工资，主要是对人工智能摄影产品进行介绍。2.引导家长扫码微信小程序注册。3.派单等现场执行工作。工作时间：上午场9:30-14:00、下午场15:30-19:30可以做半天。工作要求：1.介绍产品语言表达能力强，不可迟到早退。2.热情主动有活力勤快。3.有做过销售类工作优先，周一到周五可以持续做的优先。4.18-25岁在校大学生优先，可以做实习生。（有学生证）
# 11	高级/资深智能问答算法工程师	18	30	上海 长宁区 北新泾	1-3年	本科	互联网	已上市	10000人以上	09月16日	算法高级经理	None
# 11	C++开发工程师（人工智能方向）	18	36	上海 浦东新区 八佰伴	1-3年	硕士	计算机软件	不需要融资	1000-9999人	08月27日	招聘者	None
# 11	平面设计师	5	8	上海 长宁区 镇宁路	1年以内	大专	电子商务	不需要融资	100-499人	10月20日	总经理	None
# 11	婚礼设计	4	6	上海 静安区 和田	1年以内	大专	婚庆/摄影	未融资	20-99人	09月15日	招聘者	None
# 11	广告展览设计师	6	12	上海 闵行区 春申	经验不限	学历不限	广告/公关/会展	未融资	0-20人	08月19日	总经理	None
# 11	产品设计师	5	6	上海 浦东新区 金桥	1年以内	大专	电子商务	未融资	20-99人	09月14日	人事	None
# 11	高级Android开发工程师（AI产品）	20	40	上海 徐汇区 虹梅路	3-5年	本科	互联网	D轮及以上	100-499人	07月11日	招聘者	None
# 11	项目工程师	10	20	上海 普陀区 金沙江路	1-3年	本科	计算机软件	0-20人	None	09月17日	招聘者	None
# 11	ocr算法专家（上海）	25	40	上海  	5-10年	本科	企业服务	已上市	100-499人	06月10日	高级副总裁	None
# 11	图像算法	12	20	上海 静安区 共和新路	经验不限	本科	医疗健康	已上市	1000-9999人	08月28日	招聘者	None
# 12	AI语音智能机器人优化工程师	4	6	上海  	经验不限	学历不限	通信/网络设备	未融资	20-99人	05月16日	副总经理	None
# 12	大数据人工智能工程师 - 深度学习方向	25	35	上海 虹口区 七浦路	1-3年	本科	互联网	不需要融资	500-999人	04月12日	人力资源	None
# 12	AI工程师	15	20	上海 黄浦区 南京东路	1年以内	本科	智能硬件	0-20人	None	07月15日	CTO	None
# 12	AI算法工程师	16	20	上海 嘉定区 	3-5年	本科	计算机软件	B轮	1000-9999人	05月18日	招聘主管	None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-ce636de0936c> in <module>()
#      54       #读取每个职位的详细信息页面
#      55       link=item.find('div','info-primary').find('h3').find('a')['href']
# ---> 56       xq=getDetails(link)
#      57       shuchu.append(xq)
#      58       print('\t'.join(shuchu))
#
# <ipython-input-1-ce636de0936c> in getDetails(link)
#      14 }
#      15 def getDetails(link):
# ---> 16     xq_html=requests.get('https://www.zhipin.com'+link,headers=headers2)
#      17     xq_soup= BeautifulSoup(xq_html.text, 'html.parser')
#      18     miaoshu=''
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     593             is_new_proxy_conn = self.proxy is not None and not getattr(conn, 'sock', None)
#     594             if is_new_proxy_conn:
# --> 595                 self._prepare_proxy(conn)
#     596
#     597             # Make the request on the httplib connection object.
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _prepare_proxy(self, conn)
#     814             set_tunnel(self._proxy_host, self.port, self.proxy_headers)
#     815
# --> 816         conn.connect()
#     817
#     818     def _new_conn(self):
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     324             ca_cert_dir=self.ca_cert_dir,
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#     328         if self.assert_fingerprint:
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     327         context.load_cert_chain(certfile, keyfile)
#     328     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 329         return context.wrap_socket(sock, server_hostname=server_hostname)
#     330
#     331     warnings.warn(
#
# /anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     439         while True:
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#     443                 rd = util.wait_for_read(sock, sock.gettimeout())
#
# /anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1904         :return: None.
#    1905         """
# -> 1906         result = _lib.SSL_do_handshake(self._ssl)
#    1907         self._raise_ssl_error(self._ssl, result)
#    1908
#
# KeyboardInterrupt:
